# %%
import pandas as pd

# Paths to the CSV files
csv_files = [
    '6.csv',
    '6_cb_vq.csv',
    '12.csv',
    '12_cb_vq.csv',
    '24.csv',
    '24_cb_vq.csv',
    '48.csv',
    '48_cb_vq.csv',
    '72.csv',
    '72_cb_vq.csv',
    '120.csv',
    '120_cb_vq.csv'
]

# Load and concatenate the CSV files
df_list = [pd.read_csv(file) for file in csv_files]
combined_df = pd.concat(df_list, ignore_index=True)

combined_df.head()
# Out:
#    Unnamed: 0     Method        MAE       RMSE         R       SIM       FSD  \
# 0           0        SVR  13.560227  13.674624  0.048387  0.272079  1.330458
# 1           1      ARIMA   1.419478   1.730068  0.879800  0.795309  1.958880
# 2           2        KNN   8.000000   8.163265       NaN  0.390990  2.000000
# 3           3         RF   7.378333   8.003989 -0.597633  0.433156  1.962909
# 4           0  ARIMA_SVR   1.696437   2.113727  0.837463  0.773793  1.954737
#
#          NSE
# 0 -69.861396
# 1  -0.134241
# 2 -24.252632
# 3 -23.276824
# 4  -0.693076

# %%
combined_df.to_csv("vuquang.csv")
