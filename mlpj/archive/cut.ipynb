# %%
import pandas as pd

data=pd.read_csv('nodes.csv')
df = pd.DataFrame(data)
data.head()
# Out:
#                    node   type
# 0               2001 10  comic
# 1                2001 8  comic
# 2                2001 9  comic
# 3  24-HOUR MAN/EMMANUEL   hero
# 4  3-D MAN/CHARLES CHAN   hero

# %%
# Specify n, the row from which to cut (0-based indexing)
n = 9999

# Select only rows up to (but not including) row n
df_cut = df.iloc[:n]

df_cut.head()
df_cut.to_csv('nodes1.csv', index=False)
