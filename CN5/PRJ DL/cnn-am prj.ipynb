# %%
import os
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential,load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, Layer, Input, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, r2_score , mean_absolute_error
from tensorflow.keras.metrics import RootMeanSquaredError
from scipy.stats import pearsonr
from tensorflow import keras
import h5py

# Đặt các biến môi trường cho GPU
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
tf.get_logger().setLevel('ERROR')

physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# 2024-06-24 04:39:38.849523: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-24 04:39:38.849658: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-24 04:39:38.974617: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
df = pd.read_csv('/kaggle/input/dataset/Impute_misvalues_hungyen.csv')

df['Hour'] = df['Hour'].replace('#NUM!', 0)
df['Hour'] = pd.to_datetime(df['Hour'], format='%H', errors='coerce').dt.time
df['Hour'] = df['Hour'].astype(str)


df['DateTime'] = pd.to_datetime(
    df['Date'] + ' ' + df['Hour']
        )
df = df.set_index('DateTime')
df.drop(['Date', 'Hour'], 
        axis = 1, inplace = True)

df.plot(y='Waterlevel', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('DateTime', fontsize=12)
plt.ylabel('Waterlevel', fontsize=12)
plt.show()

# %%
train_size = int(len(df) * 0.7)
val_size = int(len(df) * 0.85)
train, val, test = df[:train_size].iloc[:, [-1]], df[train_size:val_size].iloc[:, [-1]] , df[val_size:].iloc[:, [-1]]

train, val, test
# Out:
# (                     Waterlevel
#  DateTime
#  2008-01-01 00:00:00        47.0
#  2008-01-01 01:00:00        43.0
#  2008-01-01 02:00:00        40.0
#  2008-01-01 03:00:00        37.0
#  2008-01-01 04:00:00        34.0
#  ...                         ...
#  2013-02-11 05:00:00        86.0
#  2013-02-11 06:00:00       100.0
#  2013-02-11 07:00:00       115.0
#  2013-02-11 08:00:00       128.0
#  2013-02-11 09:00:00       134.0
#
#  [44842 rows x 1 columns],
#                       Waterlevel
#  DateTime
#  2013-02-11 10:00:00       133.0
#  2013-02-11 11:00:00       127.0
#  2013-02-11 12:00:00       122.0
#  2013-02-11 13:00:00       115.0
#  2013-02-11 14:00:00       107.0
#  ...                         ...
#  2014-03-18 14:00:00        46.0
#  2014-03-18 15:00:00        54.0
#  2014-03-18 16:00:00        61.0
#  2014-03-18 17:00:00        65.0
#  2014-03-18 18:00:00        65.0
#
#  [9609 rows x 1 columns],
#                       Waterlevel
#  DateTime
#  2014-03-18 19:00:00        62.0
#  2014-03-18 20:00:00        56.0
#  2014-03-18 21:00:00        50.0
#  2014-03-18 22:00:00        44.0
#  2014-03-18 23:00:00        38.0
#  ...                         ...
#  2015-04-23 00:00:00       127.0
#  2015-04-23 01:00:00       124.0
#  2015-04-23 02:00:00       120.0
#  2015-04-23 03:00:00       115.0
#  2015-04-23 04:00:00       109.0
#
#  [9610 rows x 1 columns])

# %%
train.shape, val.shape, test.shape
# Out:
# ((44842, 1), (9609, 1), (9610, 1))

# %%
plt.figure(figsize = (15,8))
plt.plot(test.index, test['Waterlevel'], label = "test", color = 'orange')
plt.plot(val.index, val['Waterlevel'], label = "val", color = 'green')
plt.plot(train.index, train['Waterlevel'], label = "train" , color = 'blue')
plt.xlabel('DateTime', fontsize=12)
plt.ylabel('Waterlevel', fontsize=12)
# Out:
# Text(0, 0.5, 'Waterlevel')

# %%
scaler = MinMaxScaler()
train['Waterlevel'] = scaler.fit_transform(train)
val['Waterlevel'] = scaler.transform(val)
test['Waterlevel'] = scaler.transform(test)

# %%
train_data = train.values
val_data = val.values
test_data = test.values

# %%
timesteps = 164

# %%
train_data_timesteps=np.array([[j for j in train_data[i:i+timesteps]] 
                               for i in range(0,len(train_data)-timesteps+1)])[:,:,0]
val_data_timesteps=np.array([[j for j in val_data[i:i+timesteps]] 
                             for i in range(0,len(val_data)-timesteps+1)])[:,:,0]
test_data_timesteps=np.array([[j for j in test_data[i:i+timesteps]] 
                              for i in range(0,len(test_data)-timesteps+1)])[:,:,0]

# %%
x_train, y_train = train_data_timesteps[:,:timesteps-1],train_data_timesteps[:,[timesteps-1]]
x_val, y_val = val_data_timesteps[:,:timesteps-1],val_data_timesteps[:,[timesteps-1]]
x_test, y_test = test_data_timesteps[:,:timesteps-1],test_data_timesteps[:,[timesteps-1]]

x_train, y_train
# Out:
# (array([[0.10782866, 0.10192024, 0.09748892, ..., 0.17282127, 0.16395864,
#          0.15509601],
#         [0.10192024, 0.09748892, 0.09305761, ..., 0.16395864, 0.15509601,
#          0.14623338],
#         [0.09748892, 0.09305761, 0.08862629, ..., 0.15509601, 0.14623338,
#          0.13737075],
#         ...,
#         [0.1816839 , 0.17725258, 0.17282127, ..., 0.14327917, 0.16543575,
#          0.18611521],
#         [0.17725258, 0.17282127, 0.16838996, ..., 0.16543575, 0.18611521,
#          0.20827179],
#         [0.17282127, 0.16838996, 0.16395864, ..., 0.18611521, 0.20827179,
#          0.22747415]]),
#  array([[0.14623338],
#         [0.13737075],
#         [0.12998523],
#         ...,
#         [0.20827179],
#         [0.22747415],
#         [0.23633678]]))

# %%
def calculate_metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))

    squared_error = np.mean((y_true - y_pred)**2)

    r, _ = pearsonr(y_true, y_pred)
    
    T = len(y_true)
    max_x = max(y_true)
    min_x = min(y_true)
    
    sim_sum = 0
    for i in range(T):
        sim_sum += 1 / (1 + abs(y_pred[i] - y_true[i]) / (max_x - min_x))
    sim = sim_sum / T
    
    sd_y = np.std(y_pred)
    sd_x = np.std(y_test)
    fsd = 2 * np.abs(sd_y - sd_x) / (sd_y + sd_x)
    
    nse = 1 - (np.sum((y_pred - y_true) ** 2) / np.sum((y_true - np.mean(y_true)) ** 2))
    
    return {
        'MAE': mae,
        'RMSE': rmse,
        'MSE' : squared_error,
        'R': r,
        'SIM': sim,
        'FSD': fsd,
        'NSE': nse
    }

# %%
class AttentionLayer(Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W = self.add_weight(name='attention_weight', shape=(input_shape[-1], input_shape[-1]),
                                 initializer='uniform', trainable=True)
        self.b = self.add_weight(name='attention_bias', shape=(input_shape[-1],),
                                 initializer='uniform', trainable=True)
        super(AttentionLayer, self).build(input_shape)

    def call(self, x):
        e = tf.nn.tanh(tf.tensordot(x, self.W, axes=1) + self.b)
        a = tf.nn.softmax(e, axis=1)
        output = x * a
        return tf.reduce_sum(output, axis=1)

# %%
model = Sequential()

model.add(Input(shape=(timesteps, 1)))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(Conv1D(filters=128, kernel_size=3, activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(Conv1D(filters=128, kernel_size=3, activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(AttentionLayer())
model.add(AttentionLayer())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mean_squared_error'
)

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Huấn luyện mô hình
history = model.fit(x_train, y_train, epochs=100, batch_size=10, validation_data=(x_val, y_val), callbacks=[early_stopping])
# Out:
# Epoch 1/100
#   47/4468 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - loss: 0.0359
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1719204019.133028     108 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 4468/4468 ━━━━━━━━━━━━━━━━━━━━ 40s 6ms/step - loss: 0.0041 - val_loss: 4.3407e-04
# Epoch 2/100
# 4468/4468 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - loss: 7.0832e-04 - val_loss: 1.7338e-04
# Epoch 3/100
# 4468/4468 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - loss: 5.2615e-04 - val_loss: 7.9482e-04
# Epoch 4/100
# 4468/4468 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - loss: 3.7501e-04 - val_loss: 3.5338e-04
# Epoch 5/100
# 4468/4468 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - loss: 3.3908e-04 - val_loss: 5.1041e-04
# Epoch 6/100
# 4468/4468 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - loss: 2.9620e-04 - val_loss: 8.3047e-04
# Epoch 7/100
# 4468/4468 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - loss: 2.6282e-04 - val_loss: 3.7753e-04
# Epoch 8/100
# 4468/4468 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - loss: 2.3727e-04 - val_loss: 6.1138e-04
# Epoch 9/100
# 4468/4468 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - loss: 2.3547e-04 - val_loss: 8.6757e-04
# Epoch 10/100
# 4468/4468 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - loss: 2.0778e-04 - val_loss: 9.3928e-04
# Epoch 11/100
# 4468/4468 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - loss: 2.0553e-04 - val_loss: 0.0012
# Epoch 12/100
# 4468/4468 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - loss: 1.9472e-04 - val_loss: 0.0010

# %%
# model.save('CNN_AM.h5')
# model = models.load_model('CNN_AM.h5')
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 164, 64)        │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 164, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 164, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 164, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 164, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 164, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 164, 64)        │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 164, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 164, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 164, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 164, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 164, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ attention_layer                 │ (None, 128)            │        16,512 │
# │ (AttentionLayer)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ attention_layer_1               │ (None)                 │        16,512 │
# │ (AttentionLayer)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 425,669 (1.62 MB)
#  Trainable params: 141,633 (553.25 KB)
#  Non-trainable params: 768 (3.00 KB)
#  Optimizer params: 283,268 (1.08 MB)

# %%
time = 320
hours = 120
pred = []

def forecast(model, hours, time):
    pred = []
    # current_window = x_val[-1,:].tolist()
    current_window = x_test[time,:].tolist()
    for i in range(hours):
        # Chuyển current_window thành numpy array khi gọi predict
        y_pred = model.predict(np.asarray([current_window]))[0]
        pred.append(float(y_pred[0]))
        current_window.pop(0)
        current_window.append(pred[-1])
    pred_array = np.array(pred).reshape(-1, 1)
    return pred_array

y_fc = forecast(model, hours, time)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
y_pred = model.predict(x_test[time:])
# Out:
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
y_test_original = scaler.inverse_transform(y_test)
y_pred_original = scaler.inverse_transform(y_pred)
y_fc_original = scaler.inverse_transform(y_fc)

# %%
time_forecast = [3, 6,12,24,36,72,120]
for hours in time_forecast:
    plt.figure(figsize=(20, 6))
    
    plt.plot(y_test_original[time : time + hours].flatten(), label='Actual', color='blue', marker='o')
    plt.plot(y_pred_original[: hours], label='Predicted', color='red', marker='x')
    plt.plot(y_fc_original[: hours].flatten(), label='Forecast', color='green', marker='x')
    plt.title('Comparison of Actual and Predicted Values')
    plt.xlabel('Hours')
    plt.ylabel('Waterlevel')
    plt.legend()

    plt.show()

# %%
time_forecast = [3,  6, 12, 24, 36, 72, 120]
for hours in time_forecast:
    metrics = calculate_metrics(y_test_original[time : time + hours].flatten(), y_fc_original[:hours].flatten())
    for metric, value in metrics.items():
        print(f'Using model LSTM {hours} hours {metric}: {value}')

    print('\n')
# Out:
# Using model LSTM 3 hours MAE: 15.299163848161692
# Using model LSTM 3 hours RMSE: 16.836487418923053
# Using model LSTM 3 hours MSE: 283.46730860755423
# Using model LSTM 3 hours R: -0.9991142269069698
# Using model LSTM 3 hours SIM: 0.2797917998150415
# Using model LSTM 3 hours FSD: 1.9310515040159366
# Using model LSTM 3 hours NSE: -66.13699414389437
#
#
# Using model LSTM 6 hours MAE: 29.441118389368054
# Using model LSTM 6 hours RMSE: 33.468154229325286
# Using model LSTM 6 hours MSE: 1120.117347517904
# Using model LSTM 6 hours R: -0.9987023367609061
# Using model LSTM 6 hours SIM: 0.36157641519995604
# Using model LSTM 6 hours FSD: 1.9692801456132694
# Using model LSTM 6 hours NSE: -50.89732884252839
#
#
# Using model LSTM 12 hours MAE: 31.667409047484398
# Using model LSTM 12 hours RMSE: 36.30399347080129
# Using model LSTM 12 hours MSE: 1317.9799419279827
# Using model LSTM 12 hours R: 0.5437215290797367
# Using model LSTM 12 hours SIM: 0.6873453590639004
# Using model LSTM 12 hours FSD: 1.9790259297338
# Using model LSTM 12 hours NSE: -2.277934189496011
#
#
# Using model LSTM 24 hours MAE: 18.407352702071268
# Using model LSTM 24 hours RMSE: 26.057072863626004
# Using model LSTM 24 hours MSE: 678.9710462203147
# Using model LSTM 24 hours R: 0.566032371715143
# Using model LSTM 24 hours SIM: 0.8148127049766444
# Using model LSTM 24 hours FSD: 1.9741343681482304
# Using model LSTM 24 hours NSE: -0.355627405715766
#
#
# Using model LSTM 36 hours MAE: 20.84279411037763
# Using model LSTM 36 hours RMSE: 26.927019011760148
# Using model LSTM 36 hours MSE: 725.0643528596925
# Using model LSTM 36 hours R: 0.5909968567647411
# Using model LSTM 36 hours SIM: 0.7879079715086187
# Using model LSTM 36 hours FSD: 1.9705507690023694
# Using model LSTM 36 hours NSE: -0.600706935408301
#
#
# Using model LSTM 72 hours MAE: 39.74533911587462
# Using model LSTM 72 hours RMSE: 50.69343636579848
# Using model LSTM 72 hours MSE: 2569.8244905732604
# Using model LSTM 72 hours R: 0.3050993387158993
# Using model LSTM 72 hours SIM: 0.706061144738714
# Using model LSTM 72 hours FSD: 1.98879646198248
# Using model LSTM 72 hours NSE: -3.5658023173612543
#
#
# Using model LSTM 120 hours MAE: 60.31569168567656
# Using model LSTM 120 hours RMSE: 71.78644668292833
# Using model LSTM 120 hours MSE: 5153.293927360912
# Using model LSTM 120 hours R: 0.27202138684846433
# Using model LSTM 120 hours SIM: 0.6315205633730971
# Using model LSTM 120 hours FSD: 1.9909403141455901
# Using model LSTM 120 hours NSE: -6.890966124003217
