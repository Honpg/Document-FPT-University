# %%
import numpy as np
# import cupy as cp
# import numba as nb
import datetime as dt
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from scipy.stats import pearsonr
import h5py
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, Reshape
from keras.models import Sequential
from keras.optimizers import Adam

# %%
len(tf.config.list_physical_devices('GPU'))
# Out:
# 1

# %%
tf.test.is_gpu_available
# Out:
# <function tensorflow.python.framework.test_util.is_gpu_available(cuda_only=False, min_cuda_compute_capability=None)>

# %%
gpu_available = tf.test.is_gpu_available()
is_cuda_gpu_available = tf.test.is_gpu_available(cuda_only=True)
is_cuda_gpu_min_3 = tf.test.is_gpu_available(True, (3,0))
tf.test.is_gpu_available
# Out:
# <function tensorflow.python.framework.test_util.is_gpu_available(cuda_only=False, min_cuda_compute_capability=None)>

# %%
tf.test.is_gpu_available
# Out:
# <function tensorflow.python.framework.test_util.is_gpu_available(cuda_only=False, min_cuda_compute_capability=None)>

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
sns.set(style='whitegrid', palette='muted', font_scale=1.5)
rcParams['figure.figsize'] = 16, 10
# RANDOM_SEED = 42
# cp.random.seed(RANDOM_SEED)
# tf.random.set_seed(RANDOM_SEED)

# %%
df = pd.read_csv('Impute_misvalues_hungyen.csv')
df.head()
# Out:
#        Date Hour  Waterlevel
# 0  1/1/2008    0        47.0
# 1  1/1/2008    1        43.0
# 2  1/1/2008    2        40.0
# 3  1/1/2008    3        37.0
# 4  1/1/2008    4        34.0

# %%
df['Hour'] = df['Hour'].replace('#NUM!', 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64061 entries, 0 to 64060
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        64061 non-null  object
#  1   Hour        64061 non-null  object
#  2   Waterlevel  64061 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
#          Waterlevel
# count  64061.000000
# mean     138.135113
# std       97.020489
# min      -26.000000
# 25%       75.000000
# 50%      116.000000
# 75%      171.000000
# max      651.000000

# %%
df.isnull().sum()
# Out:
# Date          0
# Hour          0
# Waterlevel    0
# dtype: int64

# %%
df['Hour'] = pd.to_datetime(df['Hour'], format='%H', errors='coerce').dt.time
df.head()
# Out:
#        Date      Hour  Waterlevel
# 0  1/1/2008  00:00:00        47.0
# 1  1/1/2008  01:00:00        43.0
# 2  1/1/2008  02:00:00        40.0
# 3  1/1/2008  03:00:00        37.0
# 4  1/1/2008  04:00:00        34.0

# %%
df['Hour'] = df['Hour'].astype(str)


df['DateTime'] = pd.to_datetime(
    df['Date'] + ' ' + df['Hour']
        )
df = df.set_index('DateTime')
df.drop(['Date', 'Hour'], 
        axis = 1, inplace = True)

df.head()
# Out:
#                      Waterlevel
# DateTime
# 2008-01-01 00:00:00        47.0
# 2008-01-01 01:00:00        43.0
# 2008-01-01 02:00:00        40.0
# 2008-01-01 03:00:00        37.0
# 2008-01-01 04:00:00        34.0

# %%
df.plot(y='Waterlevel', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('DateTime', fontsize=12)
plt.ylabel('Waterlevel', fontsize=12)
plt.show()

# %%
train_size = int(len(df) * 0.7)
val_size = int(len(df) * 0.85)
train, val, test = df[:train_size].iloc[:, [-1]], df[train_size:val_size].iloc[:, [-1]] , df[val_size:].iloc[:, [-1]]

train, val, test
# Out:
# (                     Waterlevel
#  DateTime
#  2008-01-01 00:00:00        47.0
#  2008-01-01 01:00:00        43.0
#  2008-01-01 02:00:00        40.0
#  2008-01-01 03:00:00        37.0
#  2008-01-01 04:00:00        34.0
#  ...                         ...
#  2013-02-11 05:00:00        86.0
#  2013-02-11 06:00:00       100.0
#  2013-02-11 07:00:00       115.0
#  2013-02-11 08:00:00       128.0
#  2013-02-11 09:00:00       134.0
#
#  [44842 rows x 1 columns],
#                       Waterlevel
#  DateTime
#  2013-02-11 10:00:00       133.0
#  2013-02-11 11:00:00       127.0
#  2013-02-11 12:00:00       122.0
#  2013-02-11 13:00:00       115.0
#  2013-02-11 14:00:00       107.0
#  ...                         ...
#  2014-03-18 14:00:00        46.0
#  2014-03-18 15:00:00        54.0
#  2014-03-18 16:00:00        61.0
#  2014-03-18 17:00:00        65.0
#  2014-03-18 18:00:00        65.0
#
#  [9609 rows x 1 columns],
#                       Waterlevel
#  DateTime
#  2014-03-18 19:00:00        62.0
#  2014-03-18 20:00:00        56.0
#  2014-03-18 21:00:00        50.0
#  2014-03-18 22:00:00        44.0
#  2014-03-18 23:00:00        38.0
#  ...                         ...
#  2015-04-23 00:00:00       127.0
#  2015-04-23 01:00:00       124.0
#  2015-04-23 02:00:00       120.0
#  2015-04-23 03:00:00       115.0
#  2015-04-23 04:00:00       109.0
#
#  [9610 rows x 1 columns])

# %%
train.shape, val.shape, test.shape
# Out:
# ((44842, 1), (9609, 1), (9610, 1))

# %%
plt.figure(figsize = (15,8))
plt.plot(test.index, test['Waterlevel'], label = "test", color = 'orange')
plt.plot(val.index, val['Waterlevel'], label = "val", color = 'green')
plt.plot(train.index, train['Waterlevel'], label = "train" , color = 'blue')
plt.xlabel('DateTime', fontsize=12)
plt.ylabel('Waterlevel', fontsize=12)
# Out:
# Text(0, 0.5, 'Waterlevel')

# %%
scaler = MinMaxScaler()
train['Waterlevel'] = scaler.fit_transform(train)
val['Waterlevel'] = scaler.transform(val)
test['Waterlevel'] = scaler.transform(test)

# %%
train_data = train.values
val_data = val.values
test_data = test.values

# %%
timesteps = 164

# %%
train_data_timesteps=np.array([[j for j in train_data[i:i+timesteps]] 
                               for i in range(0,len(train_data)-timesteps+1)])[:,:,0]
val_data_timesteps=np.array([[j for j in val_data[i:i+timesteps]] 
                             for i in range(0,len(val_data)-timesteps+1)])[:,:,0]
test_data_timesteps=np.array([[j for j in test_data[i:i+timesteps]] 
                              for i in range(0,len(test_data)-timesteps+1)])[:,:,0]

# %%
x_train, y_train = train_data_timesteps[:,:timesteps-1],train_data_timesteps[:,[timesteps-1]]
x_val, y_val = val_data_timesteps[:,:timesteps-1],val_data_timesteps[:,[timesteps-1]]
x_test, y_test = test_data_timesteps[:,:timesteps-1],test_data_timesteps[:,[timesteps-1]]

x_train, y_train
# Out:
# (array([[0.10782866, 0.10192024, 0.09748892, ..., 0.17282127, 0.16395864,
#          0.15509601],
#         [0.10192024, 0.09748892, 0.09305761, ..., 0.16395864, 0.15509601,
#          0.14623338],
#         [0.09748892, 0.09305761, 0.08862629, ..., 0.15509601, 0.14623338,
#          0.13737075],
#         ...,
#         [0.1816839 , 0.17725258, 0.17282127, ..., 0.14327917, 0.16543575,
#          0.18611521],
#         [0.17725258, 0.17282127, 0.16838996, ..., 0.16543575, 0.18611521,
#          0.20827179],
#         [0.17282127, 0.16838996, 0.16395864, ..., 0.18611521, 0.20827179,
#          0.22747415]]),
#  array([[0.14623338],
#         [0.13737075],
#         [0.12998523],
#         ...,
#         [0.20827179],
#         [0.22747415],
#         [0.23633678]]))

# %%
def calculate_metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))

    squared_error = np.mean((y_true - y_pred)**2)

    r, _ = pearsonr(y_true, y_pred)
    
    T = len(y_true)
    max_x = max(y_true)
    min_x = min(y_true)
    
    sim_sum = 0
    for i in range(T):
        sim_sum += 1 / (1 + abs(y_pred[i] - y_true[i]) / (max_x - min_x))
    sim = sim_sum / T
    
    sd_y = np.std(y_pred)
    sd_x = np.std(y_test)
    fsd = 2 * np.abs(sd_y - sd_x) / (sd_y + sd_x)
    
    nse = 1 - (np.sum((y_pred - y_true) ** 2) / np.sum((y_true - np.mean(y_true)) ** 2))
    
    return {
        'MAE': mae,
        'RMSE': rmse,
        'MSE' : squared_error,
        'R': r,
        'SIM': sim,
        'FSD': fsd,
        'NSE': nse
    }

# %% [markdown]
# ### LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# %%
# model = keras.Sequential()

# model.add(keras.layers.LSTM(units=512, activation = 'tanh',
#                             return_sequences=True, 
#                             input_shape=(x_train.shape[1], 1)))
# model.add(Dropout(0.1))
# model.add(keras.layers.LSTM(units=256,activation = 'tanh',
#                             return_sequences=True))
# model.add(Dropout(0.1))
# model.add(keras.layers.LSTM(units=64,activation = 'tanh',
#                             return_sequences=True))
# model.add(Dropout(0.1))
# # model.add(keras.layers.LSTM(units=64,activation = 'tanh',
# #                             return_sequences=True))
# # model.add(Dropout(0.1))
# model.add(keras.layers.LSTM(units=32))
# model.add(Flatten())

# model.add(Dense(32, 'relu'))
# model.add(Dropout(0.1))
# model.add(Dense((1), 'linear'))

# model.compile(
#   loss=MeanSquaredError(),
#   optimizer=Adam(learning_rate=0.0001),
#   metrics=[RootMeanSquaredError()]
# )

# %%
model = keras.Sequential()

# model.add(keras.layers.LSTM(units=512, activation = 'tanh',
#                             return_sequences=True, 
#                             input_shape=(x_train.shape[1], 1)))
# model.add(Dropout(0.1))
# model.add(keras.layers.LSTM(units=256,activation = 'tanh',
#                             return_sequences=True))
# model.add(Dropout(0.1))
# model.add(keras.layers.LSTM(units=64,activation = 'tanh',
#                             return_sequences=True))
# model.add(Dropout(0.1))
# # model.add(keras.layers.LSTM(units=64,activation = 'tanh',
# #                             return_sequences=True))
# # model.add(Dropout(0.1))
# model.add(keras.layers.LSTM(units=32,activation = 'tanh',
#                             return_sequences=True))
# model.add(Flatten())
# model.add(Reshape((timesteps, 32)))
model.add(Conv1D(8, 3, activation='relu', padding = 'same',
                            input_shape=(x_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=2, strides=2))
model.add(Conv1D(16, 3, activation='relu', padding = 'same'))
model.add(MaxPooling1D(pool_size=2, strides=2))
model.add(Conv1D(32, 3, activation='relu', padding = 'same'))
model.add(MaxPooling1D(pool_size=2, strides=2))
model.add(Conv1D(64, 3, activation='relu', padding = 'same'))
model.add(MaxPooling1D(pool_size=2, strides=2))
model.add(Conv1D(128, 3, activation='relu', padding = 'same'))
model.add(MaxPooling1D(pool_size=2, strides=2))
model.add(Conv1D(256, 3, activation='relu', padding = 'same'))
model.add(MaxPooling1D(pool_size=2, strides=2))
# model.add(keras.layers.LSTM(units=512,activation = 'tanh',
#                             return_sequences=True))
model.add(keras.layers.LSTM(units=256,activation = 'tanh',
                            return_sequences=True))
model.add(Dropout(0.1))
# model.add(keras.layers.LSTM(units=64,activation = 'tanh',
#                             return_sequences=True))
# # model.add(Dropout(0.1))
# model.add(keras.layers.LSTM(units=32,activation = 'tanh',
#                             return_sequences=True))

model.add(Flatten())

model.add(Dense(100, 'relu'))
model.add(Dropout(0.1))
model.add(Dense((1), 'linear'))

model.compile(
  loss=MeanSquaredError(),
  optimizer=Adam(learning_rate=0.0001),
  metrics=[RootMeanSquaredError()]
)

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_20 (Conv1D)          (None, 163, 8)            32
#
#  max_pooling1d_20 (MaxPoolin  (None, 81, 8)            0
#  g1D)
#
#  conv1d_21 (Conv1D)          (None, 81, 16)            400
#
#  max_pooling1d_21 (MaxPoolin  (None, 40, 16)           0
#  g1D)
#
#  conv1d_22 (Conv1D)          (None, 40, 32)            1568
#
#  max_pooling1d_22 (MaxPoolin  (None, 20, 32)           0
#  g1D)
#
#  conv1d_23 (Conv1D)          (None, 20, 64)            6208
#
#  max_pooling1d_23 (MaxPoolin  (None, 10, 64)           0
#  g1D)
#
#  conv1d_24 (Conv1D)          (None, 10, 128)           24704
#
#  max_pooling1d_24 (MaxPoolin  (None, 5, 128)           0
#  g1D)
#
#  conv1d_25 (Conv1D)          (None, 5, 256)            98560
#
#  max_pooling1d_25 (MaxPoolin  (None, 2, 256)           0
#  g1D)
#
#  lstm_12 (LSTM)              (None, 2, 256)            525312
#
#  dropout_12 (Dropout)        (None, 2, 256)            0
#
#  flatten_6 (Flatten)         (None, 512)               0
#
#  dense_12 (Dense)            (None, 100)               51300
#
#  dropout_13 (Dropout)        (None, 100)               0
#
#  dense_13 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 708,185
# Trainable params: 708,185
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    # callbacks=[cp1],
    epochs=50,
    batch_size=32,                       
    verbose=1,
    shuffle=False
)
# Out:
# Epoch 1/50
# 1397/1397 [==============================] - 11s 7ms/step - loss: 0.0061 - root_mean_squared_error: 0.0780 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0989
# Epoch 2/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 0.0025 - root_mean_squared_error: 0.0500 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0418
# Epoch 3/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 7.7726e-04 - root_mean_squared_error: 0.0279 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0354
# Epoch 4/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 5.5792e-04 - root_mean_squared_error: 0.0236 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0385
# Epoch 5/50
# 1397/1397 [==============================] - 8s 6ms/step - loss: 6.5387e-04 - root_mean_squared_error: 0.0256 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0462
# Epoch 6/50
# 1397/1397 [==============================] - 8s 6ms/step - loss: 5.1738e-04 - root_mean_squared_error: 0.0227 - val_loss: 8.4649e-04 - val_root_mean_squared_error: 0.0291
# Epoch 7/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 5.2001e-04 - root_mean_squared_error: 0.0228 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0435
# Epoch 8/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 4.5082e-04 - root_mean_squared_error: 0.0212 - val_loss: 6.2422e-04 - val_root_mean_squared_error: 0.0250
# Epoch 9/50
# 1397/1397 [==============================] - 8s 6ms/step - loss: 4.0842e-04 - root_mean_squared_error: 0.0202 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0340
# Epoch 10/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 5.3154e-04 - root_mean_squared_error: 0.0231 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0325
# Epoch 11/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 4.0507e-04 - root_mean_squared_error: 0.0201 - val_loss: 4.5305e-04 - val_root_mean_squared_error: 0.0213
# Epoch 12/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 3.0722e-04 - root_mean_squared_error: 0.0175 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0318
# Epoch 13/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 2.9730e-04 - root_mean_squared_error: 0.0172 - val_loss: 9.8669e-04 - val_root_mean_squared_error: 0.0314
# Epoch 14/50
# 1397/1397 [==============================] - 8s 6ms/step - loss: 2.8428e-04 - root_mean_squared_error: 0.0169 - val_loss: 8.8397e-04 - val_root_mean_squared_error: 0.0297
# Epoch 15/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 2.5765e-04 - root_mean_squared_error: 0.0161 - val_loss: 7.5498e-04 - val_root_mean_squared_error: 0.0275
# Epoch 16/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 2.6785e-04 - root_mean_squared_error: 0.0164 - val_loss: 6.1477e-04 - val_root_mean_squared_error: 0.0248
# Epoch 17/50
# 1397/1397 [==============================] - 8s 6ms/step - loss: 2.8300e-04 - root_mean_squared_error: 0.0168 - val_loss: 6.3900e-04 - val_root_mean_squared_error: 0.0253
# Epoch 18/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 2.4908e-04 - root_mean_squared_error: 0.0158 - val_loss: 4.4064e-04 - val_root_mean_squared_error: 0.0210
# Epoch 19/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 2.6197e-04 - root_mean_squared_error: 0.0162 - val_loss: 6.2633e-04 - val_root_mean_squared_error: 0.0250
# Epoch 20/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 2.3357e-04 - root_mean_squared_error: 0.0153 - val_loss: 1.4223e-04 - val_root_mean_squared_error: 0.0119
# Epoch 21/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 3.9032e-04 - root_mean_squared_error: 0.0198 - val_loss: 2.5609e-04 - val_root_mean_squared_error: 0.0160
# Epoch 22/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 2.7847e-04 - root_mean_squared_error: 0.0167 - val_loss: 1.3557e-04 - val_root_mean_squared_error: 0.0116
# Epoch 23/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 1.8486e-04 - root_mean_squared_error: 0.0136 - val_loss: 3.5119e-04 - val_root_mean_squared_error: 0.0187
# Epoch 24/50
# 1397/1397 [==============================] - 8s 6ms/step - loss: 2.2556e-04 - root_mean_squared_error: 0.0150 - val_loss: 2.6512e-04 - val_root_mean_squared_error: 0.0163
# Epoch 25/50
# 1397/1397 [==============================] - 8s 6ms/step - loss: 2.0194e-04 - root_mean_squared_error: 0.0142 - val_loss: 3.1115e-04 - val_root_mean_squared_error: 0.0176
# Epoch 26/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 2.6315e-04 - root_mean_squared_error: 0.0162 - val_loss: 2.5451e-04 - val_root_mean_squared_error: 0.0160
# Epoch 27/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 2.0481e-04 - root_mean_squared_error: 0.0143 - val_loss: 2.0023e-04 - val_root_mean_squared_error: 0.0142
# Epoch 28/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 1.7430e-04 - root_mean_squared_error: 0.0132 - val_loss: 4.6937e-04 - val_root_mean_squared_error: 0.0217
# Epoch 29/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 2.8034e-04 - root_mean_squared_error: 0.0167 - val_loss: 2.1502e-04 - val_root_mean_squared_error: 0.0147
# Epoch 30/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 2.2696e-04 - root_mean_squared_error: 0.0151 - val_loss: 1.0940e-04 - val_root_mean_squared_error: 0.0105
# Epoch 31/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 1.9838e-04 - root_mean_squared_error: 0.0141 - val_loss: 1.2333e-04 - val_root_mean_squared_error: 0.0111
# Epoch 32/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 1.5720e-04 - root_mean_squared_error: 0.0125 - val_loss: 2.8389e-04 - val_root_mean_squared_error: 0.0168
# Epoch 33/50
# 1397/1397 [==============================] - 9s 7ms/step - loss: 2.3600e-04 - root_mean_squared_error: 0.0154 - val_loss: 1.8264e-04 - val_root_mean_squared_error: 0.0135
# Epoch 34/50
# 1397/1397 [==============================] - 8s 6ms/step - loss: 2.9632e-04 - root_mean_squared_error: 0.0172 - val_loss: 1.1272e-04 - val_root_mean_squared_error: 0.0106
# Epoch 35/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 2.9062e-04 - root_mean_squared_error: 0.0170 - val_loss: 1.2042e-04 - val_root_mean_squared_error: 0.0110
# Epoch 36/50
# 1397/1397 [==============================] - 9s 7ms/step - loss: 2.7809e-04 - root_mean_squared_error: 0.0167 - val_loss: 1.2855e-04 - val_root_mean_squared_error: 0.0113
# Epoch 37/50
# 1397/1397 [==============================] - 9s 7ms/step - loss: 2.5446e-04 - root_mean_squared_error: 0.0160 - val_loss: 9.6759e-05 - val_root_mean_squared_error: 0.0098
# Epoch 38/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 2.6848e-04 - root_mean_squared_error: 0.0164 - val_loss: 9.2602e-05 - val_root_mean_squared_error: 0.0096
# Epoch 39/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 2.6956e-04 - root_mean_squared_error: 0.0164 - val_loss: 1.1618e-04 - val_root_mean_squared_error: 0.0108
# Epoch 40/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 2.4308e-04 - root_mean_squared_error: 0.0156 - val_loss: 1.4154e-04 - val_root_mean_squared_error: 0.0119
# Epoch 41/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 2.3942e-04 - root_mean_squared_error: 0.0155 - val_loss: 9.0948e-05 - val_root_mean_squared_error: 0.0095
# Epoch 42/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 2.0961e-04 - root_mean_squared_error: 0.0145 - val_loss: 1.1455e-04 - val_root_mean_squared_error: 0.0107
# Epoch 43/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 1.5117e-04 - root_mean_squared_error: 0.0123 - val_loss: 1.1821e-04 - val_root_mean_squared_error: 0.0109
# Epoch 44/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 1.3627e-04 - root_mean_squared_error: 0.0117 - val_loss: 1.5140e-04 - val_root_mean_squared_error: 0.0123
# Epoch 45/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 1.5421e-04 - root_mean_squared_error: 0.0124 - val_loss: 1.2403e-04 - val_root_mean_squared_error: 0.0111
# Epoch 46/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 1.5427e-04 - root_mean_squared_error: 0.0124 - val_loss: 1.1485e-04 - val_root_mean_squared_error: 0.0107
# Epoch 47/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 1.5177e-04 - root_mean_squared_error: 0.0123 - val_loss: 1.2070e-04 - val_root_mean_squared_error: 0.0110
# Epoch 48/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 1.5214e-04 - root_mean_squared_error: 0.0123 - val_loss: 1.1386e-04 - val_root_mean_squared_error: 0.0107
# Epoch 49/50
# 1397/1397 [==============================] - 8s 6ms/step - loss: 1.3396e-04 - root_mean_squared_error: 0.0116 - val_loss: 1.5403e-04 - val_root_mean_squared_error: 0.0124
# Epoch 50/50
# 1397/1397 [==============================] - 9s 6ms/step - loss: 1.3726e-04 - root_mean_squared_error: 0.0117 - val_loss: 2.1345e-04 - val_root_mean_squared_error: 0.0146

# %%
model.save('Model_Choose_LSTM_CNN.h5')

# %%
model = keras.models.load_model('Model_Choose_LSTM_CNN.h5')

# %%
# time = int(input("Enter the first time you want to forecast:"))
time = 77
hours = 120
pred = []

def forecast(model, hours, time):
    pred = []
    # current_window = x_val[-1,:].tolist()
    current_window = x_test[time,:].tolist()
    for i in range(hours):
        # Chuyển current_window thành numpy array khi gọi predict
        y_pred = model.predict(np.asarray([current_window]))[0]
        pred.append(float(y_pred[0]))
        current_window.pop(0)
        current_window.append(pred[-1])
    pred_array = np.array(pred).reshape(-1, 1)
    return pred_array

y_fc = forecast(model, hours, time)
# Out:
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
y_pred = model.predict(x_test[time:])
# Out:
# 293/293 [==============================] - 1s 2ms/step

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_20 (Conv1D)          (None, 163, 8)            32
#
#  max_pooling1d_20 (MaxPoolin  (None, 81, 8)            0
#  g1D)
#
#  conv1d_21 (Conv1D)          (None, 81, 16)            400
#
#  max_pooling1d_21 (MaxPoolin  (None, 40, 16)           0
#  g1D)
#
#  conv1d_22 (Conv1D)          (None, 40, 32)            1568
#
#  max_pooling1d_22 (MaxPoolin  (None, 20, 32)           0
#  g1D)
#
#  conv1d_23 (Conv1D)          (None, 20, 64)            6208
#
#  max_pooling1d_23 (MaxPoolin  (None, 10, 64)           0
#  g1D)
#
#  conv1d_24 (Conv1D)          (None, 10, 128)           24704
#
#  max_pooling1d_24 (MaxPoolin  (None, 5, 128)           0
#  g1D)
#
#  conv1d_25 (Conv1D)          (None, 5, 256)            98560
#
#  max_pooling1d_25 (MaxPoolin  (None, 2, 256)           0
#  g1D)
#
#  lstm_12 (LSTM)              (None, 2, 256)            525312
#
#  dropout_12 (Dropout)        (None, 2, 256)            0
#
#  flatten_6 (Flatten)         (None, 512)               0
#
#  dense_12 (Dense)            (None, 100)               51300
#
#  dropout_13 (Dropout)        (None, 100)               0
#
#  dense_13 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 708,185
# Trainable params: 708,185
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_test_original = scaler.inverse_transform(y_test)
y_pred_original = scaler.inverse_transform(y_pred)
y_fc_original = scaler.inverse_transform(y_fc)

# %%
time_forecast = [3,  6, 12, 24, 36, 72, 120]
for hours in time_forecast:
    plt.figure(figsize=(20, 6))
    
    plt.plot(y_test_original[time : time + hours].flatten(), label='Actual', color='blue', marker='o')
    plt.plot(y_pred_original[: hours], label='Predicted', color='red', marker='x')
    plt.plot(y_fc_original[: hours].flatten(), label='Forecast', color='green', marker='x')
    plt.title('Comparison of Actual and Predicted Values')
    plt.xlabel('Hours')
    plt.ylabel('Waterlevel')
    plt.legend()

    plt.show()

# %%
time_forecast = [3,  6, 12, 24, 36, 72, 120]
for hours in time_forecast:
    metrics = calculate_metrics(y_test_original[time : time + hours].flatten(), y_fc_original[:hours].flatten())
    for metric, value in metrics.items():
        print(f'Using model LSTM {hours} hours {metric}: {value}')

    print('\n')
# Out:
# Using model LSTM 3 hours MAE: 7.077545324961339
# Using model LSTM 3 hours RMSE: 7.195997885541281
# Using model LSTM 3 hours MSE: 51.782385568714595
# Using model LSTM 3 hours R: 0.9809193782631955
# Using model LSTM 3 hours SIM: 0.6503161974949694
# Using model LSTM 3 hours FSD: 1.922578146371115
# Using model LSTM 3 hours NSE: -0.834808937474143
#
#
# Using model LSTM 6 hours MAE: 12.855222687125206
# Using model LSTM 6 hours RMSE: 14.506146090099012
# Using model LSTM 6 hours MSE: 210.42827438729486
# Using model LSTM 6 hours R: 0.45297544046377863
# Using model LSTM 6 hours SIM: 0.6536848338291789
# Using model LSTM 6 hours FSD: 1.9337679710952582
# Using model LSTM 6 hours NSE: -3.027335394972149
#
#
# Using model LSTM 12 hours MAE: 22.9819255284965
# Using model LSTM 12 hours RMSE: 25.57147875910424
# Using model LSTM 12 hours MSE: 653.9005259273193
# Using model LSTM 12 hours R: 0.9705411584276695
# Using model LSTM 12 hours SIM: 0.7804865504188808
# Using model LSTM 12 hours FSD: 1.9898300179557442
# Using model LSTM 12 hours NSE: 0.0045492670253936
#
#
# Using model LSTM 24 hours MAE: 29.5269717797637
# Using model LSTM 24 hours RMSE: 31.299394819537294
# Using model LSTM 24 hours MSE: 979.6521160692781
# Using model LSTM 24 hours R: 0.9734781217092476
# Using model LSTM 24 hours SIM: 0.7470632559821232
# Using model LSTM 24 hours FSD: 1.9899248305465012
# Using model LSTM 24 hours NSE: -0.352851132705283
#
#
# Using model LSTM 36 hours MAE: 37.68718849495053
# Using model LSTM 36 hours RMSE: 40.55214978704292
# Using model LSTM 36 hours MSE: 1644.4768523507655
# Using model LSTM 36 hours R: 0.8724680800018474
# Using model LSTM 36 hours SIM: 0.7108276408844714
# Using model LSTM 36 hours FSD: 1.9886357027082806
# Using model LSTM 36 hours NSE: -1.2374680329803684
#
#
# Using model LSTM 72 hours MAE: 50.0169572689467
# Using model LSTM 72 hours RMSE: 53.12370125676328
# Using model LSTM 72 hours MSE: 2822.127635217833
# Using model LSTM 72 hours R: 0.7555490843589314
# Using model LSTM 72 hours SIM: 0.6495016440410908
# Using model LSTM 72 hours FSD: 1.9871941974718879
# Using model LSTM 72 hours NSE: -4.60695829007383
#
#
# Using model LSTM 120 hours MAE: 59.13811860320469
# Using model LSTM 120 hours RMSE: 64.25195033307405
# Using model LSTM 120 hours MSE: 4128.313121603814
# Using model LSTM 120 hours R: 0.4498290168156034
# Using model LSTM 120 hours SIM: 0.6664303400260726
# Using model LSTM 120 hours FSD: 1.9846080207489871
# Using model LSTM 120 hours NSE: -5.539000074780106

# %% [markdown]
# ##
