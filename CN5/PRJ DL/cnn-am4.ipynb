# %%
import os
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential,load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, Layer, Input, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from scipy.stats import pearsonr
from tensorflow import keras
import h5py

# Đặt các biến môi trường cho GPU
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
tf.get_logger().setLevel('ERROR')

physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
df = pd.read_csv('/kaggle/input/dataset/Impute_misvalues_hungyen.csv')

df['Hour'] = df['Hour'].replace('#NUM!', 0)
df['Hour'] = pd.to_datetime(df['Hour'], format='%H', errors='coerce').dt.time
df['Hour'] = df['Hour'].astype(str)


df['DateTime'] = pd.to_datetime(
    df['Date'] + ' ' + df['Hour']
        )
df = df.set_index('DateTime')
df.drop(['Date', 'Hour'], 
        axis = 1, inplace = True)

df.plot(y='Waterlevel', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('DateTime', fontsize=12)
plt.ylabel('Waterlevel', fontsize=12)
plt.show()

# %%
train_size = int(len(df) * 0.7)
val_size = int(len(df) * 0.85)
train, val, test = df[:train_size].iloc[:, [-1]], df[train_size:val_size].iloc[:, [-1]] , df[val_size:].iloc[:, [-1]]

train, val, test
# Out:
# (                     Waterlevel
#  DateTime
#  2008-01-01 00:00:00        47.0
#  2008-01-01 01:00:00        43.0
#  2008-01-01 02:00:00        40.0
#  2008-01-01 03:00:00        37.0
#  2008-01-01 04:00:00        34.0
#  ...                         ...
#  2013-02-11 05:00:00        86.0
#  2013-02-11 06:00:00       100.0
#  2013-02-11 07:00:00       115.0
#  2013-02-11 08:00:00       128.0
#  2013-02-11 09:00:00       134.0
#
#  [44842 rows x 1 columns],
#                       Waterlevel
#  DateTime
#  2013-02-11 10:00:00       133.0
#  2013-02-11 11:00:00       127.0
#  2013-02-11 12:00:00       122.0
#  2013-02-11 13:00:00       115.0
#  2013-02-11 14:00:00       107.0
#  ...                         ...
#  2014-03-18 14:00:00        46.0
#  2014-03-18 15:00:00        54.0
#  2014-03-18 16:00:00        61.0
#  2014-03-18 17:00:00        65.0
#  2014-03-18 18:00:00        65.0
#
#  [9609 rows x 1 columns],
#                       Waterlevel
#  DateTime
#  2014-03-18 19:00:00        62.0
#  2014-03-18 20:00:00        56.0
#  2014-03-18 21:00:00        50.0
#  2014-03-18 22:00:00        44.0
#  2014-03-18 23:00:00        38.0
#  ...                         ...
#  2015-04-23 00:00:00       127.0
#  2015-04-23 01:00:00       124.0
#  2015-04-23 02:00:00       120.0
#  2015-04-23 03:00:00       115.0
#  2015-04-23 04:00:00       109.0
#
#  [9610 rows x 1 columns])

# %%
train.shape, val.shape, test.shape
# Out:
# ((44842, 1), (9609, 1), (9610, 1))

# %%
plt.figure(figsize = (15,8))
plt.plot(test.index, test['Waterlevel'], label = "test", color = 'orange')
plt.plot(val.index, val['Waterlevel'], label = "val", color = 'green')
plt.plot(train.index, train['Waterlevel'], label = "train" , color = 'blue')
plt.xlabel('DateTime', fontsize=12)
plt.ylabel('Waterlevel', fontsize=12)
# Out:
# Text(0, 0.5, 'Waterlevel')

# %%
scaler = MinMaxScaler()
train['Waterlevel'] = scaler.fit_transform(train)
val['Waterlevel'] = scaler.transform(val)
test['Waterlevel'] = scaler.transform(test)

# %%
train_data = train.values
val_data = val.values
test_data = test.values

# %%
timesteps = 164

# %%
train_data_timesteps=np.array([[j for j in train_data[i:i+timesteps]] 
                               for i in range(0,len(train_data)-timesteps+1)])[:,:,0]
val_data_timesteps=np.array([[j for j in val_data[i:i+timesteps]] 
                             for i in range(0,len(val_data)-timesteps+1)])[:,:,0]
test_data_timesteps=np.array([[j for j in test_data[i:i+timesteps]] 
                              for i in range(0,len(test_data)-timesteps+1)])[:,:,0]

# %%
x_train, y_train = train_data_timesteps[:,:timesteps-1],train_data_timesteps[:,[timesteps-1]]
x_val, y_val = val_data_timesteps[:,:timesteps-1],val_data_timesteps[:,[timesteps-1]]
x_test, y_test = test_data_timesteps[:,:timesteps-1],test_data_timesteps[:,[timesteps-1]]

x_train, y_train
# Out:
# (array([[0.10782866, 0.10192024, 0.09748892, ..., 0.17282127, 0.16395864,
#          0.15509601],
#         [0.10192024, 0.09748892, 0.09305761, ..., 0.16395864, 0.15509601,
#          0.14623338],
#         [0.09748892, 0.09305761, 0.08862629, ..., 0.15509601, 0.14623338,
#          0.13737075],
#         ...,
#         [0.1816839 , 0.17725258, 0.17282127, ..., 0.14327917, 0.16543575,
#          0.18611521],
#         [0.17725258, 0.17282127, 0.16838996, ..., 0.16543575, 0.18611521,
#          0.20827179],
#         [0.17282127, 0.16838996, 0.16395864, ..., 0.18611521, 0.20827179,
#          0.22747415]]),
#  array([[0.14623338],
#         [0.13737075],
#         [0.12998523],
#         ...,
#         [0.20827179],
#         [0.22747415],
#         [0.23633678]]))

# %%
def calculate_metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))

    squared_error = np.mean((y_true - y_pred)**2)

    r, _ = pearsonr(y_true, y_pred)
    
    T = len(y_true)
    max_x = max(y_true)
    min_x = min(y_true)
    
    sim_sum = 0
    for i in range(T):
        sim_sum += 1 / (1 + abs(y_pred[i] - y_true[i]) / (max_x - min_x))
    sim = sim_sum / T
    
    sd_y = np.std(y_pred)
    sd_x = np.std(y_test)
    fsd = 2 * np.abs(sd_y - sd_x) / (sd_y + sd_x)
    
    nse = 1 - (np.sum((y_pred - y_true) ** 2) / np.sum((y_true - np.mean(y_true)) ** 2))
    
    return {
        'MAE': mae,
        'RMSE': rmse,
        'MSE' : squared_error,
        'R': r,
        'SIM': sim,
        'FSD': fsd,
        'NSE': nse
    }

# %%
class AttentionLayer(Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W = self.add_weight(name='attention_weight', shape=(input_shape[-1], input_shape[-1]),
                                 initializer='uniform', trainable=True)
        self.b = self.add_weight(name='attention_bias', shape=(input_shape[-1],),
                                 initializer='uniform', trainable=True)
        super(AttentionLayer, self).build(input_shape)

    def call(self, x):
        e = tf.nn.tanh(tf.tensordot(x, self.W, axes=1) + self.b)
        a = tf.nn.softmax(e, axis=1)
        output = x * a
        return tf.reduce_sum(output, axis=1)

# %%
model = Sequential()

model.add(Input(shape=(timesteps, 1)))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(Conv1D(filters=128, kernel_size=3, activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(Conv1D(filters=128, kernel_size=3, activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(AttentionLayer())
model.add(AttentionLayer())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mean_squared_error'
)

early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

# Huấn luyện mô hình
history = model.fit(x_train, y_train, epochs=100, batch_size=15, validation_data=(x_val, y_val), callbacks=[early_stopping])
# Out:
# Epoch 1/100
#   42/2979 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0366
# W0000 00:00:1719190471.750733     106 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 33s 7ms/step - loss: 0.0044 - val_loss: 8.0485e-04
# Epoch 2/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 6.7448e-04 - val_loss: 8.6431e-04
# Epoch 3/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 4.9803e-04 - val_loss: 2.9641e-04
# Epoch 4/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 3.8234e-04 - val_loss: 0.0011
# Epoch 5/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 3.1850e-04 - val_loss: 7.0509e-04
# Epoch 6/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 2.8183e-04 - val_loss: 8.3231e-04
# Epoch 7/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 2.6713e-04 - val_loss: 3.9426e-04
# Epoch 8/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 2.4162e-04 - val_loss: 8.0644e-04
# Epoch 9/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 2.2723e-04 - val_loss: 9.1934e-04
# Epoch 10/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 2.0489e-04 - val_loss: 2.7834e-04
# Epoch 11/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 2.0089e-04 - val_loss: 7.6616e-04
# Epoch 12/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.9968e-04 - val_loss: 7.1178e-04
# Epoch 13/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.8162e-04 - val_loss: 9.3315e-04
# Epoch 14/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.7494e-04 - val_loss: 0.0014
# Epoch 15/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.6285e-04 - val_loss: 6.0393e-04
# Epoch 16/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.6655e-04 - val_loss: 4.4390e-04
# Epoch 17/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.6028e-04 - val_loss: 8.5762e-04
# Epoch 18/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.4623e-04 - val_loss: 8.3267e-04
# Epoch 19/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.6003e-04 - val_loss: 7.6835e-04
# Epoch 20/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.5278e-04 - val_loss: 7.3414e-04
# Epoch 21/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.4358e-04 - val_loss: 7.9009e-04
# Epoch 22/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.3863e-04 - val_loss: 7.6026e-04
# Epoch 23/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.2942e-04 - val_loss: 5.6608e-04
# Epoch 24/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.3541e-04 - val_loss: 6.6614e-04
# Epoch 25/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.3004e-04 - val_loss: 9.1377e-04
# Epoch 26/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.2774e-04 - val_loss: 5.8774e-04
# Epoch 27/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.3646e-04 - val_loss: 6.5578e-04
# Epoch 28/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.2530e-04 - val_loss: 7.2147e-04
# Epoch 29/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.2544e-04 - val_loss: 4.1547e-04
# Epoch 30/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.1836e-04 - val_loss: 5.4917e-04
# Epoch 31/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.1802e-04 - val_loss: 0.0011
# Epoch 32/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.1972e-04 - val_loss: 7.8780e-04
# Epoch 33/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.2033e-04 - val_loss: 9.0499e-04
# Epoch 34/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.1661e-04 - val_loss: 8.5141e-04
# Epoch 35/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.1114e-04 - val_loss: 6.0324e-04
# Epoch 36/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.1468e-04 - val_loss: 7.4157e-04
# Epoch 37/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.1087e-04 - val_loss: 7.0946e-04
# Epoch 38/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.0595e-04 - val_loss: 7.8216e-04
# Epoch 39/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.0612e-04 - val_loss: 0.0010
# Epoch 40/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 1.0807e-04 - val_loss: 7.0498e-04
# Epoch 41/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.0317e-04 - val_loss: 8.0874e-04
# Epoch 42/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.0232e-04 - val_loss: 6.7108e-04
# Epoch 43/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 9.6732e-05 - val_loss: 6.0183e-04
# Epoch 44/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 9.8444e-05 - val_loss: 0.0011
# Epoch 45/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.0090e-04 - val_loss: 6.8435e-04
# Epoch 46/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 9.7417e-05 - val_loss: 7.0173e-04
# Epoch 47/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 9.7066e-05 - val_loss: 8.4526e-04
# Epoch 48/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 9.6911e-05 - val_loss: 0.0010
# Epoch 49/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.0199e-04 - val_loss: 7.8367e-04
# Epoch 50/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 9.6027e-05 - val_loss: 7.5863e-04
# Epoch 51/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 9.3550e-05 - val_loss: 6.9971e-04
# Epoch 52/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 9.0711e-05 - val_loss: 6.5371e-04
# Epoch 53/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 9.4075e-05 - val_loss: 6.7165e-04
# Epoch 54/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 9.0204e-05 - val_loss: 6.5824e-04
# Epoch 55/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 8.9746e-05 - val_loss: 7.1556e-04
# Epoch 56/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 8.7814e-05 - val_loss: 8.5604e-04
# Epoch 57/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 8.6869e-05 - val_loss: 5.9233e-04
# Epoch 58/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 8.8104e-05 - val_loss: 7.9400e-04
# Epoch 59/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 9.0663e-05 - val_loss: 5.4457e-04
# Epoch 60/100
# 2979/2979 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 8.5705e-05 - val_loss: 8.5760e-04

# %%
# model.save('CNN_AM.h5')
# model = models.load_model('CNN_AM.h5')
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_4 (Conv1D)               │ (None, 164, 64)        │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 164, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 164, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 164, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 164, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 164, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 164, 64)        │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 164, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 164, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 164, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 164, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 164, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ attention_layer_2               │ (None, 128)            │        16,512 │
# │ (AttentionLayer)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ attention_layer_3               │ (None)                 │        16,512 │
# │ (AttentionLayer)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 425,669 (1.62 MB)
#  Trainable params: 141,633 (553.25 KB)
#  Non-trainable params: 768 (3.00 KB)
#  Optimizer params: 283,268 (1.08 MB)

# %%
time = 164
hours = 120
pred = []

def forecast(model, hours, time):
    pred = []
    # current_window = x_val[-1,:].tolist()
    current_window = x_test[time,:].tolist()
    for i in range(hours):
        # Chuyển current_window thành numpy array khi gọi predict
        y_pred = model.predict(np.asarray([current_window]))[0]
        pred.append(float(y_pred[0]))
        current_window.pop(0)
        current_window.append(pred[-1])
    pred_array = np.array(pred).reshape(-1, 1)
    return pred_array

y_fc = forecast(model, hours, time)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
y_pred = model.predict(x_test[time:])
# Out:
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step

# %%
y_test_original = scaler.inverse_transform(y_test)
y_pred_original = scaler.inverse_transform(y_pred)
y_fc_original = scaler.inverse_transform(y_fc)

# %%
time_forecast = [3, 6,12,24,36,72,120]
for hours in time_forecast:
    plt.figure(figsize=(20, 6))
    
    plt.plot(y_test_original[time : time + hours].flatten(), label='Actual', color='blue', marker='o')
    plt.plot(y_pred_original[: hours], label='Predicted', color='red', marker='x')
    plt.plot(y_fc_original[: hours].flatten(), label='Forecast', color='green', marker='x')
    plt.title('Comparison of Actual and Predicted Values')
    plt.xlabel('Hours')
    plt.ylabel('Waterlevel')
    plt.legend()

    plt.show()

# %%
time_forecast = [3,  6, 12, 24, 36, 72, 120]
for hours in time_forecast:
    metrics = calculate_metrics(y_test_original[time : time + hours].flatten(), y_fc_original[:hours].flatten())
    for metric, value in metrics.items():
        print(f'Using model LSTM {hours} hours {metric}: {value}')

    print('\n')
# Out:
# Using model LSTM 3 hours MAE: 25.209291602174442
# Using model LSTM 3 hours RMSE: 29.230923401509685
# Using model LSTM 3 hours MSE: 854.4468829049265
# Using model LSTM 3 hours R: -0.4180596147449039
# Using model LSTM 3 hours SIM: 0.10974275435826647
# Using model LSTM 3 hours FSD: 1.9759672208057746
# Using model LSTM 3 hours NSE: -1280.6703243573807
#
#
# Using model LSTM 6 hours MAE: 37.79855674256881
# Using model LSTM 6 hours RMSE: 41.33190887610851
# Using model LSTM 6 hours MSE: 1708.326691342937
# Using model LSTM 6 hours R: 0.7944248225410797
# Using model LSTM 6 hours SIM: 0.5085633863909177
# Using model LSTM 6 hours FSD: 1.9859871971446723
# Using model LSTM 6 hours NSE: -9.956665043353947
#
#
# Using model LSTM 12 hours MAE: 26.89115048572421
# Using model LSTM 12 hours RMSE: 32.16262012086133
# Using model LSTM 12 hours MSE: 1034.434133038834
# Using model LSTM 12 hours R: 0.7244285502880186
# Using model LSTM 12 hours SIM: 0.7333871759031042
# Using model LSTM 12 hours FSD: 1.9839750364499533
# Using model LSTM 12 hours NSE: -0.6448054410475812
#
#
# Using model LSTM 24 hours MAE: 27.59666509926319
# Using model LSTM 24 hours RMSE: 33.63122904414103
# Using model LSTM 24 hours MSE: 1131.059567019475
# Using model LSTM 24 hours R: 0.5548496346877978
# Using model LSTM 24 hours SIM: 0.7386506257093433
# Using model LSTM 24 hours FSD: 1.980985478746659
# Using model LSTM 24 hours NSE: -1.3574740478710683
#
#
# Using model LSTM 36 hours MAE: 35.13045929703448
# Using model LSTM 36 hours RMSE: 43.65999745305317
# Using model LSTM 36 hours MSE: 1906.1953776006096
# Using model LSTM 36 hours R: 0.1307435736999426
# Using model LSTM 36 hours SIM: 0.7519605737942551
# Using model LSTM 36 hours FSD: 1.978656675830506
# Using model LSTM 36 hours NSE: -1.6125879579249607
#
#
# Using model LSTM 72 hours MAE: 29.114730993906658
# Using model LSTM 72 hours RMSE: 36.838950767642146
# Using model LSTM 72 hours MSE: 1357.1082936607618
# Using model LSTM 72 hours R: 0.2967745934976161
# Using model LSTM 72 hours SIM: 0.790011289624246
# Using model LSTM 72 hours FSD: 1.976069585929782
# Using model LSTM 72 hours NSE: -0.7399289002301495
#
#
# Using model LSTM 120 hours MAE: 27.767369152978063
# Using model LSTM 120 hours RMSE: 35.84088344632292
# Using model LSTM 120 hours MSE: 1284.5689262129042
# Using model LSTM 120 hours R: 0.4196281937713661
# Using model LSTM 120 hours SIM: 0.8145803254185756
# Using model LSTM 120 hours FSD: 1.9762713159339016
# Using model LSTM 120 hours NSE: -0.41751500024528365
