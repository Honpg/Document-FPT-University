# %%
# !pip install cupy-cuda12x
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Requirement already satisfied: cupy-cuda12x in /opt/conda/lib/python3.10/site-packages (13.2.0)
# Requirement already satisfied: numpy<2.3,>=1.22 in /opt/conda/lib/python3.10/site-packages (from cupy-cuda12x) (1.26.4)
# Requirement already satisfied: fastrlock>=0.5 in /opt/conda/lib/python3.10/site-packages (from cupy-cuda12x) (0.8.2)

# %%
# !pip install attention
# Out:
# Requirement already satisfied: attention in /opt/conda/lib/python3.10/site-packages (5.0.0)
# Requirement already satisfied: numpy>=1.18.1 in /opt/conda/lib/python3.10/site-packages (from attention) (1.26.4)
# Requirement already satisfied: tensorflow>=2.1 in /opt/conda/lib/python3.10/site-packages (from attention) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (3.20.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (69.0.3)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (0.35.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (1.59.3)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.1->attention) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow>=2.1->attention) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.1->attention) (2.26.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.1->attention) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.1->attention) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.1->attention) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.1->attention) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.1->attention) (3.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow>=2.1->attention) (3.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.1->attention) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.1->attention) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.1->attention) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow>=2.1->attention) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.1->attention) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.1->attention) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.1->attention) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.1->attention) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow>=2.1->attention) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.1->attention) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow>=2.1->attention) (3.2.2)

# %%
import os
import numpy as np
import cupy as cp
# import numba as nb
import datetime as dt
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from scipy.stats import pearsonr
import h5py
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, Reshape
from keras.models import Sequential
from keras.optimizers import Adam

# %%
len(tf.config.list_physical_devices('GPU'))
# Out:
# 1

# %%
tf.test.is_gpu_available
# Out:
# <function tensorflow.python.framework.test_util.is_gpu_available(cuda_only=False, min_cuda_compute_capability=None)>

# %%
gpu_available = tf.test.is_gpu_available()
is_cuda_gpu_available = tf.test.is_gpu_available(cuda_only=True)
is_cuda_gpu_min_3 = tf.test.is_gpu_available(True, (3,0))
tf.test.is_gpu_available
# Out:
# <function tensorflow.python.framework.test_util.is_gpu_available(cuda_only=False, min_cuda_compute_capability=None)>

# %%
tf.test.is_gpu_available
# Out:
# <function tensorflow.python.framework.test_util.is_gpu_available(cuda_only=False, min_cuda_compute_capability=None)>

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
sns.set(style='whitegrid', palette='muted', font_scale=1.5)
rcParams['figure.figsize'] = 16, 10
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
tf.config.experimental.enable_op_determinism()

# %%
df = pd.read_csv('/kaggle/input/deep-learning-timeseries-forecast/Impute_misvalues_hungyen.csv')
df.head()
# Out:
#        Date Hour  Waterlevel
# 0  1/1/2008    0        47.0
# 1  1/1/2008    1        43.0
# 2  1/1/2008    2        40.0
# 3  1/1/2008    3        37.0
# 4  1/1/2008    4        34.0

# %%
df['Hour'] = df['Hour'].replace('#NUM!', 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64061 entries, 0 to 64060
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        64061 non-null  object
#  1   Hour        64061 non-null  object
#  2   Waterlevel  64061 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
#          Waterlevel
# count  64061.000000
# mean     138.135113
# std       97.020489
# min      -26.000000
# 25%       75.000000
# 50%      116.000000
# 75%      171.000000
# max      651.000000

# %%
df.isnull().sum()
# Out:
# Date          0
# Hour          0
# Waterlevel    0
# dtype: int64

# %%
df['Hour'] = pd.to_datetime(df['Hour'], format='%H', errors='coerce').dt.time
df.head()
# Out:
#        Date      Hour  Waterlevel
# 0  1/1/2008  00:00:00        47.0
# 1  1/1/2008  01:00:00        43.0
# 2  1/1/2008  02:00:00        40.0
# 3  1/1/2008  03:00:00        37.0
# 4  1/1/2008  04:00:00        34.0

# %%
df['Hour'] = df['Hour'].astype(str)


df['DateTime'] = pd.to_datetime(
    df['Date'] + ' ' + df['Hour']
        )
df = df.set_index('DateTime')
df.drop(['Date', 'Hour'], 
        axis = 1, inplace = True)

df.head()
# Out:
#                      Waterlevel
# DateTime
# 2008-01-01 00:00:00        47.0
# 2008-01-01 01:00:00        43.0
# 2008-01-01 02:00:00        40.0
# 2008-01-01 03:00:00        37.0
# 2008-01-01 04:00:00        34.0

# %%
df.plot(y='Waterlevel', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('DateTime', fontsize=12)
plt.ylabel('Waterlevel', fontsize=12)
plt.show()

# %%
train_size = int(len(df) * 0.7)
val_size = int(len(df) * 0.85)
train, val, test = df[:train_size].iloc[:, [-1]], df[train_size:val_size].iloc[:, [-1]] , df[val_size:].iloc[:, [-1]]

train, val, test
# Out:
# (                     Waterlevel
#  DateTime
#  2008-01-01 00:00:00        47.0
#  2008-01-01 01:00:00        43.0
#  2008-01-01 02:00:00        40.0
#  2008-01-01 03:00:00        37.0
#  2008-01-01 04:00:00        34.0
#  ...                         ...
#  2013-02-11 05:00:00        86.0
#  2013-02-11 06:00:00       100.0
#  2013-02-11 07:00:00       115.0
#  2013-02-11 08:00:00       128.0
#  2013-02-11 09:00:00       134.0
#
#  [44842 rows x 1 columns],
#                       Waterlevel
#  DateTime
#  2013-02-11 10:00:00       133.0
#  2013-02-11 11:00:00       127.0
#  2013-02-11 12:00:00       122.0
#  2013-02-11 13:00:00       115.0
#  2013-02-11 14:00:00       107.0
#  ...                         ...
#  2014-03-18 14:00:00        46.0
#  2014-03-18 15:00:00        54.0
#  2014-03-18 16:00:00        61.0
#  2014-03-18 17:00:00        65.0
#  2014-03-18 18:00:00        65.0
#
#  [9609 rows x 1 columns],
#                       Waterlevel
#  DateTime
#  2014-03-18 19:00:00        62.0
#  2014-03-18 20:00:00        56.0
#  2014-03-18 21:00:00        50.0
#  2014-03-18 22:00:00        44.0
#  2014-03-18 23:00:00        38.0
#  ...                         ...
#  2015-04-23 00:00:00       127.0
#  2015-04-23 01:00:00       124.0
#  2015-04-23 02:00:00       120.0
#  2015-04-23 03:00:00       115.0
#  2015-04-23 04:00:00       109.0
#
#  [9610 rows x 1 columns])

# %%
train.shape, val.shape, test.shape
# Out:
# ((44842, 1), (9609, 1), (9610, 1))

# %%
plt.figure(figsize = (15,8))
plt.plot(test.index, test['Waterlevel'], label = "test", color = 'orange')
plt.plot(val.index, val['Waterlevel'], label = "val", color = 'green')
plt.plot(train.index, train['Waterlevel'], label = "train" , color = 'blue')
plt.xlabel('DateTime', fontsize=12)
plt.ylabel('Waterlevel', fontsize=12)
# Out:
# Text(0, 0.5, 'Waterlevel')

# %%
scaler = MinMaxScaler()
train['Waterlevel'] = scaler.fit_transform(train)
val['Waterlevel'] = scaler.transform(val)
test['Waterlevel'] = scaler.transform(test)

# %%
train_data = train.values
val_data = val.values
test_data = test.values

# %%
timesteps = 164

# %%
train_data_timesteps=np.array([[j for j in train_data[i:i+timesteps]] 
                               for i in range(0,len(train_data)-timesteps+1)])[:,:,0]
val_data_timesteps=np.array([[j for j in val_data[i:i+timesteps]] 
                             for i in range(0,len(val_data)-timesteps+1)])[:,:,0]
test_data_timesteps=np.array([[j for j in test_data[i:i+timesteps]] 
                              for i in range(0,len(test_data)-timesteps+1)])[:,:,0]

# %%
x_train, y_train = train_data_timesteps[:,:timesteps-1],train_data_timesteps[:,[timesteps-1]]
x_val, y_val = val_data_timesteps[:,:timesteps-1],val_data_timesteps[:,[timesteps-1]]
x_test, y_test = test_data_timesteps[:,:timesteps-1],test_data_timesteps[:,[timesteps-1]]

x_train, y_train
# Out:
# (array([[0.10782866, 0.10192024, 0.09748892, ..., 0.17282127, 0.16395864,
#          0.15509601],
#         [0.10192024, 0.09748892, 0.09305761, ..., 0.16395864, 0.15509601,
#          0.14623338],
#         [0.09748892, 0.09305761, 0.08862629, ..., 0.15509601, 0.14623338,
#          0.13737075],
#         ...,
#         [0.1816839 , 0.17725258, 0.17282127, ..., 0.14327917, 0.16543575,
#          0.18611521],
#         [0.17725258, 0.17282127, 0.16838996, ..., 0.16543575, 0.18611521,
#          0.20827179],
#         [0.17282127, 0.16838996, 0.16395864, ..., 0.18611521, 0.20827179,
#          0.22747415]]),
#  array([[0.14623338],
#         [0.13737075],
#         [0.12998523],
#         ...,
#         [0.20827179],
#         [0.22747415],
#         [0.23633678]]))

# %%
def calculate_metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))

    squared_error = np.mean((y_true - y_pred)**2)

    r, _ = pearsonr(y_true, y_pred)
    
    T = len(y_true)
    max_x = max(y_true)
    min_x = min(y_true)
    
    sim_sum = 0
    for i in range(T):
        sim_sum += 1 / (1 + abs(y_pred[i] - y_true[i]) / (max_x - min_x))
    sim = sim_sum / T
    
    sd_y = np.std(y_pred)
    sd_x = np.std(y_test)
    fsd = 2 * np.abs(sd_y - sd_x) / (sd_y + sd_x)
    
    nse = 1 - (np.sum((y_pred - y_true) ** 2) / np.sum((y_true - np.mean(y_true)) ** 2))
    
    return {
        'MAE': mae,
        'RMSE': rmse,
        'MSE' : squared_error,
        'R': r,
        'SIM': sim,
        'FSD': fsd,
        'NSE': nse
    }

# %%
pip install keras
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Requirement already satisfied: keras in /opt/conda/lib/python3.10/site-packages (2.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# %%
class AttentionLayer(Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W = self.add_weight(name='attention_weight', shape=(input_shape[-1], input_shape[-1]),
                                 initializer='uniform', trainable=True)
        self.b = self.add_weight(name='attention_bias', shape=(input_shape[-1],),
                                 initializer='uniform', trainable=True)
        super(AttentionLayer, self).build(input_shape)

    def call(self, x):
        e = tf.nn.tanh(tf.tensordot(x, self.W, axes=1) + self.b)
        a = tf.nn.softmax(e, axis=1)
        output = x * a
        return tf.reduce_sum(output, axis=1)

# %% [markdown]
# # CNN-LSTM

# %%
# model_5 = keras.Sequential()

# model_5.add(Conv1D(8, 3, activation='relu', padding = 'same',
#                             input_shape=(x_train.shape[1], 1)))
# model_5.add(MaxPooling1D(pool_size=2, strides=2))
# model_5.add(Conv1D(16, 3, activation='relu', padding = 'same'))
# model_5.add(MaxPooling1D(pool_size=2, strides=2))
# model_5.add(Conv1D(32, 3, activation='relu', padding = 'same'))
# model_5.add(MaxPooling1D(pool_size=2, strides=2))
# model_5.add(Conv1D(64, 3, activation='relu', padding = 'same'))
# model_5.add(MaxPooling1D(pool_size=2, strides=2))
# model_5.add(Conv1D(128, 3, activation='relu', padding = 'same'))
# model_5.add(MaxPooling1D(pool_size=2, strides=2))
# model_5.add(Conv1D(256, 3, activation='relu', padding = 'same'))
# model_5.add(MaxPooling1D(pool_size=2, strides=2))
# model_5.add(keras.layers.LSTM(units=256,activation = 'tanh'))
# model_5.add(Dropout(0.1))
# model_5.add(Flatten())

# model_5.add(Dense(100, 'relu'))
# model_5.add(Dropout(0.1))
# model_5.add(Dense((1), 'linear'))

# model_5.compile(
#   loss=MeanSquaredError(),
#   optimizer=Adam(learning_rate=0.0001),
#   metrics=[RootMeanSquaredError()]
# )

# model_5.fit(
#     x_train, y_train,
#     validation_data=(x_val, y_val),
#     epochs=200,
#     batch_size=32,                       
#     verbose=1,
#     shuffle=False
# )                                               
# # model_5.save('Model_5.h5')
# model_5.summary()

# %% [markdown]
# # CNN-LSTM-es

# %%
# model_5 = keras.Sequential()

# model_5.add(Conv1D(8, 3, activation='relu', padding = 'same',
#                             input_shape=(x_train.shape[1], 1)))
# model_5.add(MaxPooling1D(pool_size=2, strides=2))
# model_5.add(Conv1D(16, 3, activation='relu', padding = 'same'))
# model_5.add(MaxPooling1D(pool_size=2, strides=2))
# model_5.add(Conv1D(32, 3, activation='relu', padding = 'same'))
# model_5.add(MaxPooling1D(pool_size=2, strides=2))
# model_5.add(Conv1D(64, 3, activation='relu', padding = 'same'))
# model_5.add(MaxPooling1D(pool_size=2, strides=2))
# model_5.add(Conv1D(128, 3, activation='relu', padding = 'same'))
# model_5.add(MaxPooling1D(pool_size=2, strides=2))
# model_5.add(Conv1D(256, 3, activation='relu', padding = 'same'))
# model_5.add(MaxPooling1D(pool_size=2, strides=2))
# model_5.add(keras.layers.LSTM(units=256,activation = 'tanh'))
# model_5.add(Dropout(0.1))
# model_5.add(Flatten())

# model_5.add(Dense(100, 'relu'))
# model_5.add(Dropout(0.1))
# model_5.add(Dense((1), 'linear'))

# model_5.compile(
#   loss=MeanSquaredError(),
#   optimizer=Adam(learning_rate=0.0001),
#   metrics=[RootMeanSquaredError()]
# )

# model_5.fit(
#     x_train, y_train,
#     validation_data=(x_val, y_val),
#     epochs=200,
#     batch_size=32,
#     callbacks=[EarlyStopping(monitor='val_loss', 
#                              patience=10, 
#                              restore_best_weights=True)],                       
#     verbose=1,
#     shuffle=False
# )                                               
# # model_5.save('Model_5.h5')
# model_5.summary()

# %%
# time = int(input("Enter the first time you want to forecast:"))
time = 77
hours = 120
pred = []

def forecast(model, hours, time):
    pred = []
    # current_window = x_val[-1,:].tolist()
    current_window = x_test[time,:].tolist()
    for i in range(hours):
        # Chuyển current_window thành numpy array khi gọi predict
        y_pred = model.predict(np.asarray([current_window]))[0]
        pred.append(float(y_pred[0]))
        current_window.pop(0)
        current_window.append(pred[-1])
    pred_array = np.array(pred).reshape(-1, 1)
    return pred_array

# %%
# y_fc = forecast(model_5, hours, time)
# y_pred = model_5.predict(x_test[time:])

# y_test_original = scaler.inverse_transform(y_test)
# y_pred_original = scaler.inverse_transform(y_pred)
# y_fc_original = scaler.inverse_transform(y_fc)

# time_forecast = [3,  6, 12, 24, 36, 72, 120]
# for hours in time_forecast:
#     plt.figure(figsize=(20, 6))
    
#     plt.plot(y_test_original[time : time + hours].flatten(), label='Actual', color='blue', marker='o')
#     plt.plot(y_pred_original[: hours], label='Predicted', color='red', marker='x')
#     plt.plot(y_fc_original[: hours].flatten(), label='Forecast', color='green', marker='x')
#     plt.title('Comparison of Actual and Predicted Values')
#     plt.xlabel('Hours')
#     plt.ylabel('Waterlevel')
#     plt.legend()

#     plt.show()
    
# for hours in time_forecast:
#     metrics = calculate_metrics(y_test_original[time : time + hours].flatten(), y_fc_original[:hours].flatten())
#     for metric, value in metrics.items():
#         print(f'Using model LSTM {hours} hours {metric}: {value}')

#     print('\n')

# %%
# model_5.save('cnn_lstm_es.h5')

# %% [markdown]
# # LSTM

# %%
model_LSTM = keras.Sequential()

model_LSTM.add(keras.layers.LSTM(units=512, activation = 'tanh',
                            return_sequences=True, 
                            input_shape=(x_train.shape[1], 1)))
model_LSTM.add(Dropout(0.1))
model_LSTM.add(keras.layers.LSTM(units=256,activation = 'tanh',
                            return_sequences=True))
model_LSTM.add(Dropout(0.1))
model_LSTM.add(keras.layers.LSTM(units=64,activation = 'tanh',
                            return_sequences=True))
model_LSTM.add(Dropout(0.1))
model_LSTM.add(keras.layers.LSTM(units=32))
model_LSTM.add(Flatten())
model_LSTM.add(Dense(32, 'relu'))
model_LSTM.add(Dropout(0.1))
model_LSTM.add(Dense((1), 'linear'))

model_LSTM.compile(
  loss=MeanSquaredError(),
  optimizer=Adam(learning_rate=0.0001),
  metrics=[RootMeanSquaredError()]
)
model_LSTM.summary()
model_LSTM.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=100,
    batch_size=32,                       
    verbose=1,
    shuffle=False
)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 163, 512)          1052672
#
#  dropout_8 (Dropout)         (None, 163, 512)          0
#
#  lstm_9 (LSTM)               (None, 163, 256)          787456
#
#  dropout_9 (Dropout)         (None, 163, 256)          0
#
#  lstm_10 (LSTM)              (None, 163, 64)           82176
#
#  dropout_10 (Dropout)        (None, 163, 64)           0
#
#  lstm_11 (LSTM)              (None, 32)                12416
#
#  flatten_2 (Flatten)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1935809 (7.38 MB)
# Trainable params: 1935809 (7.38 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 1397/1397 [==============================] - 79s 52ms/step - loss: 0.0047 - root_mean_squared_error: 0.0682 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0735
# Epoch 2/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 0.0029 - root_mean_squared_error: 0.0536 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0380
# Epoch 3/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 0.0021 - root_mean_squared_error: 0.0464 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0358
# Epoch 4/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 0.0015 - root_mean_squared_error: 0.0388 - val_loss: 9.3631e-04 - val_root_mean_squared_error: 0.0306
# Epoch 5/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 0.0013 - root_mean_squared_error: 0.0358 - val_loss: 5.7821e-04 - val_root_mean_squared_error: 0.0240
# Epoch 6/100
# 1397/1397 [==============================] - 71s 50ms/step - loss: 0.0012 - root_mean_squared_error: 0.0345 - val_loss: 4.4546e-04 - val_root_mean_squared_error: 0.0211
# Epoch 7/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 0.0011 - root_mean_squared_error: 0.0337 - val_loss: 4.6920e-04 - val_root_mean_squared_error: 0.0217
# Epoch 8/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 8.2496e-04 - root_mean_squared_error: 0.0287 - val_loss: 4.6701e-04 - val_root_mean_squared_error: 0.0216
# Epoch 9/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 7.5385e-04 - root_mean_squared_error: 0.0275 - val_loss: 3.5101e-04 - val_root_mean_squared_error: 0.0187
# Epoch 10/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 7.4029e-04 - root_mean_squared_error: 0.0272 - val_loss: 3.3848e-04 - val_root_mean_squared_error: 0.0184
# Epoch 11/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 7.3734e-04 - root_mean_squared_error: 0.0272 - val_loss: 2.4917e-04 - val_root_mean_squared_error: 0.0158
# Epoch 12/100
# 1397/1397 [==============================] - 70s 50ms/step - loss: 7.3835e-04 - root_mean_squared_error: 0.0272 - val_loss: 3.5835e-04 - val_root_mean_squared_error: 0.0189
# Epoch 13/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 5.7573e-04 - root_mean_squared_error: 0.0240 - val_loss: 2.1220e-04 - val_root_mean_squared_error: 0.0146
# Epoch 14/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 5.7135e-04 - root_mean_squared_error: 0.0239 - val_loss: 2.4125e-04 - val_root_mean_squared_error: 0.0155
# Epoch 15/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 6.3619e-04 - root_mean_squared_error: 0.0252 - val_loss: 2.1497e-04 - val_root_mean_squared_error: 0.0147
# Epoch 16/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 4.8645e-04 - root_mean_squared_error: 0.0221 - val_loss: 1.8021e-04 - val_root_mean_squared_error: 0.0134
# Epoch 17/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 5.8061e-04 - root_mean_squared_error: 0.0241 - val_loss: 1.6747e-04 - val_root_mean_squared_error: 0.0129
# Epoch 18/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 4.4334e-04 - root_mean_squared_error: 0.0211 - val_loss: 1.6928e-04 - val_root_mean_squared_error: 0.0130
# Epoch 19/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 5.3752e-04 - root_mean_squared_error: 0.0232 - val_loss: 2.0884e-04 - val_root_mean_squared_error: 0.0145
# Epoch 20/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 4.3978e-04 - root_mean_squared_error: 0.0210 - val_loss: 1.4478e-04 - val_root_mean_squared_error: 0.0120
# Epoch 21/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 4.1715e-04 - root_mean_squared_error: 0.0204 - val_loss: 1.1834e-04 - val_root_mean_squared_error: 0.0109
# Epoch 22/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 4.3273e-04 - root_mean_squared_error: 0.0208 - val_loss: 1.1877e-04 - val_root_mean_squared_error: 0.0109
# Epoch 23/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 3.5457e-04 - root_mean_squared_error: 0.0188 - val_loss: 7.6612e-05 - val_root_mean_squared_error: 0.0088
# Epoch 24/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 3.8241e-04 - root_mean_squared_error: 0.0196 - val_loss: 7.1995e-05 - val_root_mean_squared_error: 0.0085
# Epoch 25/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 3.3409e-04 - root_mean_squared_error: 0.0183 - val_loss: 6.6814e-05 - val_root_mean_squared_error: 0.0082
# Epoch 26/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 3.6556e-04 - root_mean_squared_error: 0.0191 - val_loss: 6.0528e-05 - val_root_mean_squared_error: 0.0078
# Epoch 27/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.9653e-04 - root_mean_squared_error: 0.0172 - val_loss: 5.5759e-05 - val_root_mean_squared_error: 0.0075
# Epoch 28/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 4.1478e-04 - root_mean_squared_error: 0.0204 - val_loss: 6.7286e-05 - val_root_mean_squared_error: 0.0082
# Epoch 29/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.8742e-04 - root_mean_squared_error: 0.0170 - val_loss: 4.8774e-05 - val_root_mean_squared_error: 0.0070
# Epoch 30/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 3.4175e-04 - root_mean_squared_error: 0.0185 - val_loss: 6.7017e-05 - val_root_mean_squared_error: 0.0082
# Epoch 31/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 3.1403e-04 - root_mean_squared_error: 0.0177 - val_loss: 5.0150e-05 - val_root_mean_squared_error: 0.0071
# Epoch 32/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.8916e-04 - root_mean_squared_error: 0.0170 - val_loss: 6.0528e-05 - val_root_mean_squared_error: 0.0078
# Epoch 33/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.8633e-04 - root_mean_squared_error: 0.0169 - val_loss: 3.7656e-05 - val_root_mean_squared_error: 0.0061
# Epoch 34/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 3.5415e-04 - root_mean_squared_error: 0.0188 - val_loss: 5.9233e-05 - val_root_mean_squared_error: 0.0077
# Epoch 35/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.6527e-04 - root_mean_squared_error: 0.0163 - val_loss: 3.7790e-05 - val_root_mean_squared_error: 0.0061
# Epoch 36/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.7514e-04 - root_mean_squared_error: 0.0166 - val_loss: 4.0275e-05 - val_root_mean_squared_error: 0.0063
# Epoch 37/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.9727e-04 - root_mean_squared_error: 0.0172 - val_loss: 3.6997e-05 - val_root_mean_squared_error: 0.0061
# Epoch 38/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.8511e-04 - root_mean_squared_error: 0.0169 - val_loss: 2.8336e-05 - val_root_mean_squared_error: 0.0053
# Epoch 39/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.5281e-04 - root_mean_squared_error: 0.0159 - val_loss: 3.2780e-05 - val_root_mean_squared_error: 0.0057
# Epoch 40/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 3.2702e-04 - root_mean_squared_error: 0.0181 - val_loss: 2.9148e-05 - val_root_mean_squared_error: 0.0054
# Epoch 41/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.6548e-04 - root_mean_squared_error: 0.0163 - val_loss: 5.4037e-05 - val_root_mean_squared_error: 0.0074
# Epoch 42/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.7595e-04 - root_mean_squared_error: 0.0166 - val_loss: 2.6467e-05 - val_root_mean_squared_error: 0.0051
# Epoch 43/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.6816e-04 - root_mean_squared_error: 0.0164 - val_loss: 4.1929e-05 - val_root_mean_squared_error: 0.0065
# Epoch 44/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.7191e-04 - root_mean_squared_error: 0.0165 - val_loss: 2.3217e-05 - val_root_mean_squared_error: 0.0048
# Epoch 45/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.7081e-04 - root_mean_squared_error: 0.0165 - val_loss: 3.3615e-05 - val_root_mean_squared_error: 0.0058
# Epoch 46/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.6145e-04 - root_mean_squared_error: 0.0162 - val_loss: 2.9529e-05 - val_root_mean_squared_error: 0.0054
# Epoch 47/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.7841e-04 - root_mean_squared_error: 0.0167 - val_loss: 2.7451e-05 - val_root_mean_squared_error: 0.0052
# Epoch 48/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.4666e-04 - root_mean_squared_error: 0.0157 - val_loss: 2.2535e-05 - val_root_mean_squared_error: 0.0047
# Epoch 49/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.6260e-04 - root_mean_squared_error: 0.0162 - val_loss: 2.2065e-05 - val_root_mean_squared_error: 0.0047
# Epoch 50/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.6128e-04 - root_mean_squared_error: 0.0162 - val_loss: 2.9606e-05 - val_root_mean_squared_error: 0.0054
# Epoch 51/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.6486e-04 - root_mean_squared_error: 0.0163 - val_loss: 1.9197e-05 - val_root_mean_squared_error: 0.0044
# Epoch 52/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.6433e-04 - root_mean_squared_error: 0.0163 - val_loss: 2.3242e-05 - val_root_mean_squared_error: 0.0048
# Epoch 53/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.3605e-04 - root_mean_squared_error: 0.0154 - val_loss: 2.4698e-05 - val_root_mean_squared_error: 0.0050
# Epoch 54/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.5531e-04 - root_mean_squared_error: 0.0160 - val_loss: 1.7455e-05 - val_root_mean_squared_error: 0.0042
# Epoch 55/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.3388e-04 - root_mean_squared_error: 0.0153 - val_loss: 1.9489e-05 - val_root_mean_squared_error: 0.0044
# Epoch 56/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.4615e-04 - root_mean_squared_error: 0.0157 - val_loss: 1.6650e-05 - val_root_mean_squared_error: 0.0041
# Epoch 57/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.6950e-04 - root_mean_squared_error: 0.0164 - val_loss: 2.0393e-05 - val_root_mean_squared_error: 0.0045
# Epoch 58/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.4156e-04 - root_mean_squared_error: 0.0155 - val_loss: 2.2731e-05 - val_root_mean_squared_error: 0.0048
# Epoch 59/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.4462e-04 - root_mean_squared_error: 0.0156 - val_loss: 1.8431e-05 - val_root_mean_squared_error: 0.0043
# Epoch 60/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.6074e-04 - root_mean_squared_error: 0.0161 - val_loss: 2.9464e-05 - val_root_mean_squared_error: 0.0054
# Epoch 61/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.4347e-04 - root_mean_squared_error: 0.0156 - val_loss: 1.4902e-05 - val_root_mean_squared_error: 0.0039
# Epoch 62/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.3675e-04 - root_mean_squared_error: 0.0154 - val_loss: 3.8089e-05 - val_root_mean_squared_error: 0.0062
# Epoch 63/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.4240e-04 - root_mean_squared_error: 0.0156 - val_loss: 1.4746e-05 - val_root_mean_squared_error: 0.0038
# Epoch 64/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.4422e-04 - root_mean_squared_error: 0.0156 - val_loss: 3.7602e-05 - val_root_mean_squared_error: 0.0061
# Epoch 65/100
# 1397/1397 [==============================] - 72s 52ms/step - loss: 2.4288e-04 - root_mean_squared_error: 0.0156 - val_loss: 1.7150e-05 - val_root_mean_squared_error: 0.0041
# Epoch 66/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.4560e-04 - root_mean_squared_error: 0.0157 - val_loss: 1.5353e-05 - val_root_mean_squared_error: 0.0039
# Epoch 67/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.5796e-04 - root_mean_squared_error: 0.0161 - val_loss: 1.8322e-05 - val_root_mean_squared_error: 0.0043
# Epoch 68/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.3501e-04 - root_mean_squared_error: 0.0153 - val_loss: 2.1786e-05 - val_root_mean_squared_error: 0.0047
# Epoch 69/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.4713e-04 - root_mean_squared_error: 0.0157 - val_loss: 2.4540e-05 - val_root_mean_squared_error: 0.0050
# Epoch 70/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.5885e-04 - root_mean_squared_error: 0.0161 - val_loss: 1.9199e-05 - val_root_mean_squared_error: 0.0044
# Epoch 71/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.1711e-04 - root_mean_squared_error: 0.0147 - val_loss: 2.1442e-05 - val_root_mean_squared_error: 0.0046
# Epoch 72/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.5635e-04 - root_mean_squared_error: 0.0160 - val_loss: 2.2537e-05 - val_root_mean_squared_error: 0.0047
# Epoch 73/100
# 1397/1397 [==============================] - 72s 52ms/step - loss: 2.5886e-04 - root_mean_squared_error: 0.0161 - val_loss: 3.0585e-05 - val_root_mean_squared_error: 0.0055
# Epoch 74/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.4500e-04 - root_mean_squared_error: 0.0157 - val_loss: 3.0280e-05 - val_root_mean_squared_error: 0.0055
# Epoch 75/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.5475e-04 - root_mean_squared_error: 0.0160 - val_loss: 1.6100e-05 - val_root_mean_squared_error: 0.0040
# Epoch 76/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.4539e-04 - root_mean_squared_error: 0.0157 - val_loss: 2.2696e-05 - val_root_mean_squared_error: 0.0048
# Epoch 77/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.4342e-04 - root_mean_squared_error: 0.0156 - val_loss: 1.4169e-05 - val_root_mean_squared_error: 0.0038
# Epoch 78/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.2986e-04 - root_mean_squared_error: 0.0152 - val_loss: 9.3329e-05 - val_root_mean_squared_error: 0.0097
# Epoch 79/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.1808e-04 - root_mean_squared_error: 0.0148 - val_loss: 3.1561e-05 - val_root_mean_squared_error: 0.0056
# Epoch 80/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.4059e-04 - root_mean_squared_error: 0.0155 - val_loss: 2.8200e-05 - val_root_mean_squared_error: 0.0053
# Epoch 81/100
# 1397/1397 [==============================] - 72s 52ms/step - loss: 2.2896e-04 - root_mean_squared_error: 0.0151 - val_loss: 5.3186e-05 - val_root_mean_squared_error: 0.0073
# Epoch 82/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.2652e-04 - root_mean_squared_error: 0.0151 - val_loss: 1.4359e-05 - val_root_mean_squared_error: 0.0038
# Epoch 83/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.1317e-04 - root_mean_squared_error: 0.0146 - val_loss: 3.7569e-05 - val_root_mean_squared_error: 0.0061
# Epoch 84/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.1907e-04 - root_mean_squared_error: 0.0148 - val_loss: 3.0953e-05 - val_root_mean_squared_error: 0.0056
# Epoch 85/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.2595e-04 - root_mean_squared_error: 0.0150 - val_loss: 1.5704e-05 - val_root_mean_squared_error: 0.0040
# Epoch 86/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.4120e-04 - root_mean_squared_error: 0.0155 - val_loss: 1.5460e-05 - val_root_mean_squared_error: 0.0039
# Epoch 87/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.2634e-04 - root_mean_squared_error: 0.0150 - val_loss: 1.7264e-05 - val_root_mean_squared_error: 0.0042
# Epoch 88/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.1563e-04 - root_mean_squared_error: 0.0147 - val_loss: 3.4249e-05 - val_root_mean_squared_error: 0.0059
# Epoch 89/100
# 1397/1397 [==============================] - 72s 52ms/step - loss: 2.1012e-04 - root_mean_squared_error: 0.0145 - val_loss: 1.8419e-05 - val_root_mean_squared_error: 0.0043
# Epoch 90/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.0072e-04 - root_mean_squared_error: 0.0142 - val_loss: 5.4968e-05 - val_root_mean_squared_error: 0.0074
# Epoch 91/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.2289e-04 - root_mean_squared_error: 0.0149 - val_loss: 3.8137e-05 - val_root_mean_squared_error: 0.0062
# Epoch 92/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.5095e-04 - root_mean_squared_error: 0.0158 - val_loss: 1.3138e-05 - val_root_mean_squared_error: 0.0036
# Epoch 93/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.4064e-04 - root_mean_squared_error: 0.0155 - val_loss: 2.2783e-05 - val_root_mean_squared_error: 0.0048
# Epoch 94/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.1793e-04 - root_mean_squared_error: 0.0148 - val_loss: 1.2294e-05 - val_root_mean_squared_error: 0.0035
# Epoch 95/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.2261e-04 - root_mean_squared_error: 0.0149 - val_loss: 2.0162e-05 - val_root_mean_squared_error: 0.0045
# Epoch 96/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.0241e-04 - root_mean_squared_error: 0.0142 - val_loss: 1.6891e-05 - val_root_mean_squared_error: 0.0041
# Epoch 97/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 2.1060e-04 - root_mean_squared_error: 0.0145 - val_loss: 2.1908e-05 - val_root_mean_squared_error: 0.0047
# Epoch 98/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.3262e-04 - root_mean_squared_error: 0.0153 - val_loss: 4.2790e-05 - val_root_mean_squared_error: 0.0065
# Epoch 99/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.0601e-04 - root_mean_squared_error: 0.0144 - val_loss: 2.5418e-05 - val_root_mean_squared_error: 0.0050
# Epoch 100/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 2.3565e-04 - root_mean_squared_error: 0.0154 - val_loss: 1.9031e-05 - val_root_mean_squared_error: 0.0044

# %%
y_fc = forecast(model_LSTM, hours, time)
y_pred = model_LSTM.predict(x_test[time:])

y_test_original = scaler.inverse_transform(y_test)
y_pred_original = scaler.inverse_transform(y_pred)
y_fc_original = scaler.inverse_transform(y_fc)

time_forecast = [3,  6, 12, 24, 36, 72, 120]
for hours in time_forecast:
    plt.figure(figsize=(20, 6))
    
    plt.plot(y_test_original[time : time + hours].flatten(), label='Actual', color='blue', marker='o')
    plt.plot(y_pred_original[: hours], label='Predicted', color='red', marker='x')
    plt.plot(y_fc_original[: hours].flatten(), label='Forecast', color='green', marker='x')
    plt.title('Comparison of Actual and Predicted Values')
    plt.xlabel('Hours')
    plt.ylabel('Waterlevel')
    plt.legend()

    plt.show()
    
for hours in time_forecast:
    metrics = calculate_metrics(y_test_original[time : time + hours].flatten(), y_fc_original[:hours].flatten())
    for metric, value in metrics.items():
        print(f'Using model LSTM {hours} hours {metric}: {value}')

    print('\n')
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 293/293 [==============================] - 6s 19ms/step
# Using model LSTM 3 hours MAE: 4.3866458684205965
# Using model LSTM 3 hours RMSE: 5.20252164726936
# Using model LSTM 3 hours MSE: 27.066231490306293
# Using model LSTM 3 hours R: 0.9920477181112587
# Using model LSTM 3 hours SIM: 0.7673372074103696
# Using model LSTM 3 hours FSD: 1.8678596890311858
# Using model LSTM 3 hours NSE: 0.04096030152457808
#
#
# Using model LSTM 6 hours MAE: 13.075163981566826
# Using model LSTM 6 hours RMSE: 16.28654723501478
# Using model LSTM 6 hours MSE: 265.2516208383676
# Using model LSTM 6 hours R: -0.11258603930201597
# Using model LSTM 6 hours SIM: 0.6771935686886246
# Using model LSTM 6 hours FSD: 1.9399048055687091
# Using model LSTM 6 hours NSE: -4.076586044753445
#
#
# Using model LSTM 12 hours MAE: 21.965366323168073
# Using model LSTM 12 hours RMSE: 24.68262359817578
# Using model LSTM 12 hours MSE: 609.2319076892239
# Using model LSTM 12 hours R: 0.9533822030704691
# Using model LSTM 12 hours SIM: 0.7893227822784796
# Using model LSTM 12 hours FSD: 1.989326943513044
# Using model LSTM 12 hours NSE: 0.07254953159624244
#
#
# Using model LSTM 24 hours MAE: 23.111024032346904
# Using model LSTM 24 hours RMSE: 24.522929967860758
# Using model LSTM 24 hours MSE: 601.3740942086032
# Using model LSTM 24 hours R: 0.9738198906162632
# Using model LSTM 24 hours SIM: 0.7894560791026618
# Using model LSTM 24 hours FSD: 1.9890079548256423
# Using model LSTM 24 hours NSE: 0.16953211126204615
#
#
# Using model LSTM 36 hours MAE: 29.893200826520722
# Using model LSTM 36 hours RMSE: 32.70334743358426
# Using model LSTM 36 hours MSE: 1069.5089333617225
# Using model LSTM 36 hours R: 0.8898410127789445
# Using model LSTM 36 hours SIM: 0.7560033633862822
# Using model LSTM 36 hours FSD: 1.9879622545534803
# Using model LSTM 36 hours NSE: -0.455169190106278
#
#
# Using model LSTM 72 hours MAE: 40.442593826291464
# Using model LSTM 72 hours RMSE: 43.82573577394993
# Using model LSTM 72 hours MSE: 1920.695116128075
# Using model LSTM 72 hours R: 0.7723077459147618
# Using model LSTM 72 hours SIM: 0.6973503053498693
# Using model LSTM 72 hours FSD: 1.9868124844054218
# Using model LSTM 72 hours NSE: -2.8160065015087015
#
#
# Using model LSTM 120 hours MAE: 49.64660426843911
# Using model LSTM 120 hours RMSE: 55.131945644378554
# Using model LSTM 120 hours MSE: 3039.531430534711
# Using model LSTM 120 hours R: 0.48688102662693794
# Using model LSTM 120 hours SIM: 0.7056981255470239
# Using model LSTM 120 hours FSD: 1.984111075984723
# Using model LSTM 120 hours NSE: -3.814435258690237

# %%
model_LSTM.save('lstm.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # LSTM-es

# %%
model_LSTM1 = keras.Sequential()

model_LSTM1.add(keras.layers.LSTM(units=512, activation = 'tanh',
                            return_sequences=True, 
                            input_shape=(x_train.shape[1], 1)))
model_LSTM1.add(Dropout(0.1))
model_LSTM1.add(keras.layers.LSTM(units=256,activation = 'tanh',
                            return_sequences=True))
model_LSTM1.add(Dropout(0.1))
model_LSTM1.add(keras.layers.LSTM(units=64,activation = 'tanh',
                            return_sequences=True))
model_LSTM1.add(Dropout(0.1))
model_LSTM1.add(keras.layers.LSTM(units=32))
model_LSTM1.add(Flatten())
model_LSTM1.add(Dense(32, 'relu'))
model_LSTM1.add(Dropout(0.1))
model_LSTM1.add(Dense((1), 'linear'))

model_LSTM1.compile(
  loss=MeanSquaredError(),
  optimizer=Adam(learning_rate=0.0001),
  metrics=[RootMeanSquaredError()]
)
model_LSTM1.summary()
model_LSTM1.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=100,
    batch_size=32,
    callbacks=[EarlyStopping(monitor='val_loss', 
                             patience=10, 
                             restore_best_weights=True)],                       
    verbose=1,
    shuffle=False
)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 163, 512)          1052672
#
#  dropout_12 (Dropout)        (None, 163, 512)          0
#
#  lstm_13 (LSTM)              (None, 163, 256)          787456
#
#  dropout_13 (Dropout)        (None, 163, 256)          0
#
#  lstm_14 (LSTM)              (None, 163, 64)           82176
#
#  dropout_14 (Dropout)        (None, 163, 64)           0
#
#  lstm_15 (LSTM)              (None, 32)                12416
#
#  flatten_3 (Flatten)         (None, 32)                0
#
#  dense_6 (Dense)             (None, 32)                1056
#
#  dropout_15 (Dropout)        (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1935809 (7.38 MB)
# Trainable params: 1935809 (7.38 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 1397/1397 [==============================] - 80s 53ms/step - loss: 0.0054 - root_mean_squared_error: 0.0734 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0745
# Epoch 2/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 0.0030 - root_mean_squared_error: 0.0552 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0423
# Epoch 3/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 0.0021 - root_mean_squared_error: 0.0462 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0369
# Epoch 4/100
# 1397/1397 [==============================] - 71s 51ms/step - loss: 0.0017 - root_mean_squared_error: 0.0414 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0338
# Epoch 5/100
# 1397/1397 [==============================] - 72s 51ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384 - val_loss: 6.9994e-04 - val_root_mean_squared_error: 0.0265
# Epoch 6/100
# 1397/1397 [==============================] - 72s 52ms/step - loss: 0.0106 - root_mean_squared_error: 0.1030 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1302
# Epoch 7/100
# 1397/1397 [==============================] - 72s 52ms/step - loss: 0.0104 - root_mean_squared_error: 0.1020 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1371
# Epoch 8/100
# 1397/1397 [==============================] - 73s 52ms/step - loss: 0.0104 - root_mean_squared_error: 0.1021 - val_loss: 0.0191 - val_root_mean_squared_error: 0.1382
# Epoch 9/100
# 1397/1397 [==============================] - 73s 52ms/step - loss: 0.0104 - root_mean_squared_error: 0.1017 - val_loss: 0.0191 - val_root_mean_squared_error: 0.1381
# Epoch 10/100
# 1397/1397 [==============================] - 72s 52ms/step - loss: 0.0107 - root_mean_squared_error: 0.1036 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1347
# Epoch 11/100
# 1397/1397 [==============================] - 72s 52ms/step - loss: 0.0100 - root_mean_squared_error: 0.0999 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1294
# Epoch 12/100
# 1397/1397 [==============================] - 72s 52ms/step - loss: 0.0131 - root_mean_squared_error: 0.1143 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1303
# Epoch 13/100
# 1397/1397 [==============================] - 73s 52ms/step - loss: 0.0127 - root_mean_squared_error: 0.1129 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1360
# Epoch 14/100
# 1397/1397 [==============================] - 72s 52ms/step - loss: 0.0157 - root_mean_squared_error: 0.1251 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1349
# Epoch 15/100
# 1397/1397 [==============================] - 72s 52ms/step - loss: 0.0158 - root_mean_squared_error: 0.1258 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1357

# %%
y_fc = forecast(model_LSTM1, hours, time)
y_pred = model_LSTM1.predict(x_test[time:])

y_test_original = scaler.inverse_transform(y_test)
y_pred_original = scaler.inverse_transform(y_pred)
y_fc_original = scaler.inverse_transform(y_fc)

time_forecast = [3,  6, 12, 24, 36, 72, 120]
for hours in time_forecast:
    plt.figure(figsize=(20, 6))
    
    plt.plot(y_test_original[time : time + hours].flatten(), label='Actual', color='blue', marker='o')
    plt.plot(y_pred_original[: hours], label='Predicted', color='red', marker='x')
    plt.plot(y_fc_original[: hours].flatten(), label='Forecast', color='green', marker='x')
    plt.title('Comparison of Actual and Predicted Values')
    plt.xlabel('Hours')
    plt.ylabel('Waterlevel')
    plt.legend()

    plt.show()
    
for hours in time_forecast:
    metrics = calculate_metrics(y_test_original[time : time + hours].flatten(), y_fc_original[:hours].flatten())
    for metric, value in metrics.items():
        print(f'Using model LSTM {hours} hours {metric}: {value}')

    print('\n')
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 293/293 [==============================] - 6s 20ms/step
# Using model LSTM 3 hours MAE: 2.0191149090727123
# Using model LSTM 3 hours RMSE: 2.143029510111783
# Using model LSTM 3 hours MSE: 4.592575481209948
# Using model LSTM 3 hours R: 0.9928890136807671
# Using model LSTM 3 hours SIM: 0.8674981437897319
# Using model LSTM 3 hours FSD: 1.9004590092864815
# Using model LSTM 3 hours NSE: 0.8372709475161826
#
#
# Using model LSTM 6 hours MAE: 8.118362656484047
# Using model LSTM 6 hours RMSE: 10.995269826851313
# Using model LSTM 6 hours MSE: 120.8959585652669
# Using model LSTM 6 hours R: 0.12023449329717217
# Using model LSTM 6 hours SIM: 0.7711478742124314
# Using model LSTM 6 hours FSD: 1.9412370763426707
# Using model LSTM 6 hours NSE: -1.3137982500529541
#
#
# Using model LSTM 12 hours MAE: 14.520038448895013
# Using model LSTM 12 hours RMSE: 16.84045088218212
# Using model LSTM 12 hours MSE: 283.6007859151886
# Using model LSTM 12 hours R: 0.9545967599341184
# Using model LSTM 12 hours SIM: 0.8491024057873063
# Using model LSTM 12 hours FSD: 1.9885411475368004
# Using model LSTM 12 hours NSE: 0.568266733214361
#
#
# Using model LSTM 24 hours MAE: 16.549960209367175
# Using model LSTM 24 hours RMSE: 17.989052615647864
# Using model LSTM 24 hours MSE: 323.6060140085472
# Using model LSTM 24 hours R: 0.9761220136316933
# Using model LSTM 24 hours SIM: 0.8398440533924233
# Using model LSTM 24 hours FSD: 1.988948415458204
# Using model LSTM 24 hours NSE: 0.5531160955806628
#
#
# Using model LSTM 36 hours MAE: 20.646843583012622
# Using model LSTM 36 hours RMSE: 23.009282802920396
# Using model LSTM 36 hours MSE: 529.4270951047683
# Using model LSTM 36 hours R: 0.9333789388130834
# Using model LSTM 36 hours SIM: 0.8170422208977818
# Using model LSTM 36 hours FSD: 1.9882371517775774
# Using model LSTM 36 hours NSE: 0.2796638034781487
#
#
# Using model LSTM 72 hours MAE: 31.9559349031705
# Using model LSTM 72 hours RMSE: 36.76081182737293
# Using model LSTM 72 hours MSE: 1351.3572862075216
# Using model LSTM 72 hours R: 0.7858672863617827
# Using model LSTM 72 hours SIM: 0.749539128172185
# Using model LSTM 72 hours FSD: 1.9882770749504743
# Using model LSTM 72 hours NSE: -1.6848551582848899
#
#
# Using model LSTM 120 hours MAE: 43.199359115026894
# Using model LSTM 120 hours RMSE: 53.77027277107603
# Using model LSTM 120 hours MSE: 2891.24223387592
# Using model LSTM 120 hours R: 0.28784134729054284
# Using model LSTM 120 hours SIM: 0.7469636728900377
# Using model LSTM 120 hours FSD: 1.9877894929238837
# Using model LSTM 120 hours NSE: -3.5795540761155467

# %%
model_LSTM1.save('lstm_es.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # LSTM-AM

# %%
model_lstm_am = keras.Sequential()

model_lstm_am.add(keras.layers.LSTM(units=512, activation = 'tanh',
                            return_sequences=True, 
                            input_shape=(x_train.shape[1], 1)))
model_lstm_am.add(Dropout(0.1))
model_lstm_am.add(keras.layers.LSTM(units=256,activation = 'tanh',
                            return_sequences=True))
model_lstm_am.add(Dropout(0.1))
model_lstm_am.add(keras.layers.LSTM(units=64,activation = 'tanh',
                            return_sequences=True))
model_lstm_am.add(Dropout(0.1))
model_lstm_am.add(keras.layers.LSTM(units=32))

model_lstm_am.add(AttentionLayer())

model_lstm_am.add(Flatten())
model_lstm_am.add(Dense(32, 'relu'))
model_lstm_am.add(Dropout(0.1))
model_lstm_am.add(Dense((1), 'linear'))

model_lstm_am.compile(
  loss=MeanSquaredError(),
  optimizer=Adam(learning_rate=0.0001),
  metrics=[RootMeanSquaredError()]
)
model_lstm_am.summary()
model_lstm_am.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=100,
    batch_size=32,                       
    verbose=1,
    shuffle=False
)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_16 (LSTM)              (None, 163, 512)          1052672
#
#  dropout_16 (Dropout)        (None, 163, 512)          0
#
#  lstm_17 (LSTM)              (None, 163, 256)          787456
#
#  dropout_17 (Dropout)        (None, 163, 256)          0
#
#  lstm_18 (LSTM)              (None, 163, 64)           82176
#
#  dropout_18 (Dropout)        (None, 163, 64)           0
#
#  lstm_19 (LSTM)              (None, 32)                12416
#
#  attention_layer_2 (Attenti  (None,)                   1056
#  onLayer)
#
#  flatten_4 (Flatten)         (None, 1)                 0
#
#  dense_8 (Dense)             (None, 32)                64
#
#  dropout_19 (Dropout)        (None, 32)                0
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1935873 (7.38 MB)
# Trainable params: 1935873 (7.38 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 1397/1397 [==============================] - 81s 54ms/step - loss: 0.0183 - root_mean_squared_error: 0.1354 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1306
# Epoch 2/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0170 - root_mean_squared_error: 0.1305 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1237
# Epoch 3/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0224 - root_mean_squared_error: 0.1498 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1226
# Epoch 4/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0232 - root_mean_squared_error: 0.1524 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225
# Epoch 5/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0234 - root_mean_squared_error: 0.1530 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225
# Epoch 6/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0236 - root_mean_squared_error: 0.1536 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225
# Epoch 7/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0236 - root_mean_squared_error: 0.1536 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225
# Epoch 8/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0237 - root_mean_squared_error: 0.1538 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225
# Epoch 9/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0202 - root_mean_squared_error: 0.1422 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1364
# Epoch 10/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0117 - root_mean_squared_error: 0.1082 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1328
# Epoch 11/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0100 - root_mean_squared_error: 0.1001 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1292
# Epoch 12/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0102 - root_mean_squared_error: 0.1009 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1373
# Epoch 13/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0110 - root_mean_squared_error: 0.1047 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1378
# Epoch 14/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0093 - root_mean_squared_error: 0.0966 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1324
# Epoch 15/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0158 - root_mean_squared_error: 0.1258 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225
# Epoch 16/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0230 - root_mean_squared_error: 0.1515 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225
# Epoch 17/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0234 - root_mean_squared_error: 0.1531 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225
# Epoch 18/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0235 - root_mean_squared_error: 0.1535 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225
# Epoch 19/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0236 - root_mean_squared_error: 0.1537 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225
# Epoch 20/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0237 - root_mean_squared_error: 0.1540 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225
# Epoch 21/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0237 - root_mean_squared_error: 0.1540 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1226
# Epoch 22/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0237 - root_mean_squared_error: 0.1541 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225
# Epoch 23/100
# 1397/1397 [==============================] - 74s 53ms/step - loss: 0.0237 - root_mean_squared_error: 0.1541 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225
# Epoch 24/100
# 1224/1397 [=========================>....] - ETA: 8s - loss: 0.0235 - root_mean_squared_error: 0.1533

# %%
y_fc = forecast(model_lstm_am, hours, time)
y_pred = model_lstm_am.predict(x_test[time:])

y_test_original = scaler.inverse_transform(y_test)
y_pred_original = scaler.inverse_transform(y_pred)
y_fc_original = scaler.inverse_transform(y_fc)

time_forecast = [3,  6, 12, 24, 36, 72, 120]
for hours in time_forecast:
    plt.figure(figsize=(20, 6))
    
    plt.plot(y_test_original[time : time + hours].flatten(), label='Actual', color='blue', marker='o')
    plt.plot(y_pred_original[: hours], label='Predicted', color='red', marker='x')
    plt.plot(y_fc_original[: hours].flatten(), label='Forecast', color='green', marker='x')
    plt.title('Comparison of Actual and Predicted Values')
    plt.xlabel('Hours')
    plt.ylabel('Waterlevel')
    plt.legend()

    plt.show()
    
for hours in time_forecast:
    metrics = calculate_metrics(y_test_original[time : time + hours].flatten(), y_fc_original[:hours].flatten())
    for metric, value in metrics.items():
        print(f'Using model LSTM {hours} hours {metric}: {value}')

    print('\n')

# %%
model_lstm_am.save('lstm_am.h5')

# %% [markdown]
# # LSTM-AM-es

# %%
model_lstm_am_es = keras.Sequential()

model_lstm_am_es.add(keras.layers.LSTM(units=512, activation = 'tanh',
                            return_sequences=True, 
                            input_shape=(x_train.shape[1], 1)))
model_lstm_am_es.add(Dropout(0.1))
model_lstm_am_es.add(keras.layers.LSTM(units=256,activation = 'tanh',
                            return_sequences=True))
model_lstm_am_es.add(Dropout(0.1))
model_lstm_am_es.add(keras.layers.LSTM(units=64,activation = 'tanh',
                            return_sequences=True))
model_lstm_am_es.add(Dropout(0.1))
model_lstm_am_es.add(keras.layers.LSTM(units=32))

model_lstm_am_es.add(AttentionLayer())

model_lstm_am_es.add(Flatten())
model_lstm_am_es.add(Dense(32, 'relu'))
model_lstm_am_es.add(Dropout(0.1))
model_lstm_am_es.add(Dense((1), 'linear'))

model_lstm_am_es.compile(
  loss=MeanSquaredError(),
  optimizer=Adam(learning_rate=0.0001),
  metrics=[RootMeanSquaredError()]
)
model_lstm_am_es.summary()
model_lstm_am_es.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    callbacks=[EarlyStopping(monitor='val_loss', 
                             patience=10, 
                             restore_best_weights=True)],
    epochs=100,
    batch_size=32,                       
    verbose=1,
    shuffle=False
)

# %%
y_fc = forecast(model_lstm_am_es, hours, time)
y_pred = model_lstm_am_es.predict(x_test[time:])

y_test_original = scaler.inverse_transform(y_test)
y_pred_original = scaler.inverse_transform(y_pred)
y_fc_original = scaler.inverse_transform(y_fc)

time_forecast = [3,  6, 12, 24, 36, 72, 120]
for hours in time_forecast:
    plt.figure(figsize=(20, 6))
    
    plt.plot(y_test_original[time : time + hours].flatten(), label='Actual', color='blue', marker='o')
    plt.plot(y_pred_original[: hours], label='Predicted', color='red', marker='x')
    plt.plot(y_fc_original[: hours].flatten(), label='Forecast', color='green', marker='x')
    plt.title('Comparison of Actual and Predicted Values')
    plt.xlabel('Hours')
    plt.ylabel('Waterlevel')
    plt.legend()

    plt.show()
    
for hours in time_forecast:
    metrics = calculate_metrics(y_test_original[time : time + hours].flatten(), y_fc_original[:hours].flatten())
    for metric, value in metrics.items():
        print(f'Using model LSTM {hours} hours {metric}: {value}')

    print('\n')

# %%
model_lstm_am_es.save('lstm_am_es.h5')
